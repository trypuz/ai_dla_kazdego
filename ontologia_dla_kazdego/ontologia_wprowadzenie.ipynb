# %% [markdown]
# Przewodnik ontologa
# ============================
#
# ## Dlaczego ontologia to ontologia?
#
# ### Pytanie bez sensu
#
# Pytanie „Dlaczego ontologia jest ontologią” jest zwykle (a może nawet jedynie) stawiane przez filozofów w momencie pierwszego kontaktu z ontologiami tworzonymi w informatyce.
#
# Filozof wie, że ontologia filozoficzna jest ogólną teorią bytu mającą ambicje zrozumieć ów byt we wszelkich jego postaciach (zarówno tych aktualnych jak i tych możliwych) poprzez analizę jego budowy, pochodzenia, sposobu istnienia, funkcji, posiadanych cech, relacji z innymi bytami, itd.
#
# Filozof zastanawia się na ile wytwory informatyków nazywane „ontologiami” przypominają znane mu ontologie filozoficzne.
#
# Dla nie-filozofów związek produktów informatycznych z filozofią jest zwykle niczym więcej jak ciekawostką.
#
#
#
# ### A może jednak to pytanie nie jest całkiem bez sensu?
#
# Ontologie informatyczne łączy z ontologiami filozoficznymi potrzeba opisu rzeczywistości żywiona przez ich twórców.
#
# Potrzeba ta ma jednak w obu przypadkach inne źródła i motywacje.
#
# Filozof-ontolog  posiada potrzebę zrozumienia świata dla samej radości rozumienia, a stworzona przez niego ontologia ma mu w tym pomóc.
#
# Informatyk-ontolog również potrzebuje zrozumieć świat, ale zwykle ogranicza się do dość wąskich obszarów rzeczywistości (np. obszar samochodów używanych) a jego ostatecznym celem jest taka postać ontologii, która znajdzie swoje praktyczne zastosowanie w systemach komputerowych.
#
# Kolejna różnica między podejściem filozofa-ontologa i informatyka-ontologa wiąże się z ich stosunkiem do języka.
#
# Informatyk-ontolog zawsze troszczy się, aby jego wytwory ontologiczne były zapisane w języku zrozumiałym dla komputera lub przynajmniej miały formę teorii logicznej, którą w prosty sposób można na takie języki przeformułować.
#
# Przez „język zrozumiały dla komputera” należy rozumieć „język ustandaryzowany, bezpośrednio przetwarzalny przez odpowiednie algorytmy komputerowe”.
#
# Filozof-ontolog nie zawsze dba o logiczną postać swoich teorii filozoficznych.
#
# ## RDF pierwszy stopień ontologicznej inicjacji
#
# ### RDF – Resource Description Framework
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Rdf_logo.svg"
#      alt="RDF logo"
#      style="float: right; margin-right: 10px;" width="100" height="100"/>
#
# Resource Description Framework, czyli system opisu zasobów
# RDF jest standardem kodowania metadanych.
# Metadane to takie dane, które są meta, czyli służą do opisu innych danych.
# Pierwsza wersja standardu RDF została wydana przez W3C w 1997 roku (nota bene razem ze pierwszą specyfikacją języka XML). Przypadek?
# Standard RDF jest jednym z filarów Semantycznego Internetu (Semantic Web).
#
#
# ### Dwa kluczowe założenia dotyczące RDF
#
# Wszystko jest zasobem (resource). Wypowiadamy się tylko o zasobach identyfikowanych adresem internetowym.
# O zasobach wypowiadamy się za pomocą prostych zdań zwanych trójkami RDF postaci:
#
# `(podmiot, orzeczenie, dopełnienie)`
#
# [RYSUNEK 1]
#
# URI – Uniform Resource Identifier (ujednolicony identyfikator zasobu).
#
# [RYSUNEK 2]
#
# Graf RDF = zbiór trójek RDF
#
# - `(podmiot, orzeczenie, dopełnienie)`
# - `(podmiot, predykat, obiekt)`
# - `(obiekt, właściwość, wartość)`
#
# Podmiot:
#
# - Odnośnik URI
# - Węzeł anonimowy
#
# Orzecznik:
#
# - Odnośnik URI
#
# Dopełnienie:
#
# - Odnośnik URI
# - Węzeł anonimowy
# - Literał
#
# [RYSUNEK 3]
#
# ### URI a hiperłącza
#
# Rola powiązań RDF wybiega daleko poza koncepcję/mechanizm odnośników na stronach WWW.
# Powiązania w RDF są „etykietowane”.
# Powiązania RDF mogą łączyć te same zasoby na różne sposoby, np. oddające różne punkty widzenia. Nie istnieją natomiast zasadniczo różne rodzaje hiperłączy.
# Powiązanie RDF nie są też przewidziane do bezpośredniego wykorzystania jak hierłącza.
# Hiperłącza może zamieszczać na stronie WWW jedynie osoba zarządzająca stroną. Powiązania RDF może tworzyć każdy.
# Zasoby to nie tylko strony WWW! Za pomocą RDF można opisywać np. pliki mp3 czy zdjęcia.
# Najważniejsze: zasoby do których odnosimy się w trójkach RDF nie muszą być faktycznie „czymś” zapisanym na dysku jakiegoś komputera. URI zasobów nie muszą wskazywać plików – mogą reprezentować dowolne obiekty/byty obecne w świecie rzeczywistym.
# To co utworzymy za pomocą języka RDF, również jest zasobem internetowym.
#
#
#
# Znaczenie danego URI zależy od właściciela domeny (jego pożądane interpretacja jest umowna).
# RDF oferuje jednolity, rekursywny, elastyczny i potężny w swojej prostocie model danych
# przystosowany do zapisu różnego rodzaju informacji
# Pierwszym krokiem tworzenia grafu RDF dla pewnej dziedziny jest przydzielenie pewnego wydzielonego adresu (np. http://makolab.pl/vocab) jako identyfikatora/bazy słownika nazw zasobów.
# Odnośnik URI zasobu składa się z bazy, po którym następuje znak „/” lub „#”, a następnie identyfikator danego fragmentu (np. http://makolab.pl/vocab/Departament).
# W odnośniki URI rozróżniane są małe i duże litery!
# Każdy zasób musi posiadać identyfikator IRI (Internationalized Resource Identifier). W IRI mogą pojawić się znaki z Uniwersalnego Zestawu Znaków (UCS – Universal Character Set) określonego przez normę ISO/IEC 10646. IRI jest uogólnieniem URI (tylko znaki ASCII). URL jest ważnym przykładem URI.
#
#
# ### XML vs. RDF(S)
#
#
# XML
#
# Służy ujednoliceniu struktury (składni) przechowywanej informacji.
# Każe ujmować w ramy prostej, ustalonej struktury znaczników i atrybutów (zasady zagnieżdżania znaczników).
# Dostarcza np. zasad składniowych dla dokumentów tekstowych.
#
# RDF
#
# Ujednolica podstawową jednostkę informacji: trójkę, stanowiącą najprostszy rodzaj zdania.
# W centrum uwagi jest nie składnia (syntaksa) ale jej znaczenie (semantyka).
# Skupia się na wykorzystywanym słownictwie, w szczególności orzeczeniach (zob. RDFS i OWL).
# Umożliwia przeprowadzanie wnioskowania, w wyniku którego kolekcję janiwe wyspecyfikowanych trójek możemy uzupełnić o trójki z nich wynikające, ale jawnie niepodane.
