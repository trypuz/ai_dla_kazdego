# %% [markdown]
# # Inżynieria ontologii
#
# Motto wykładu
#
# > Smoka pokonać trudno, ale starać się trzeba.
# > (B. Chmielowski, *Nowe Ateny*, 1745–1746)

# %% [markdown]
# ## Smok, czyli struktura wykładu
#
# - Sen o golemach
# - Kontekst, czyli sztuczna inteligencja
#     - Wprowadzenie
#     - Czy maszyna może w ogóle coś wiedzieć?
#     - Oldskulowe sposoby reprezentacji wiedzy
#         - Wiedza w tekście
#         - Wiedz w bazie danych Wiedza na rysunkach (JDD)
# - Matka jest tylko jedna, czyli ontologia filozoficzna
# - Alecochodzi...
# - Inżynieria ontologii – skok na bungee
# - Inżynieria ontologii – grzybobranie
#     - Cyc
#     - DOLCE
#     - BFO
#     - CIDOC
#     - CRM
#     - ISO 15926
#     - WordNet
#     - DBpedia

# %% [markdown]
# ## Sen o golemach
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/golem.jpg?raw=1" alt="golem" width="400"/>
#
# Golemy – wczoraj i dziś
#
# -   <http://www.sztetl.org.pl/pl/article/chelm/9,legendy-i-opowiadania/15242,rabbi-eliasz-z-chelma-i-golem/?action=viewtable>
#
# -   <https://www.youtube.com/watch?v=P0Obm0DBvwI>
#
# -   <https://pl.wikipedia.org/wiki/Watson_(superkomputer)>

# %% [markdown]
# ## Kontekst, czyli sztuczna inteligencja

# %% [markdown]
# ### Golem naszych marzeń
#
# -   pomaga znaleźć wiedzę
#
# -   sam szuka wiedzy
#
# -   wytwarza wiedzę
#
# -   dzieli się wiedzą z innymi
#
# -   wie, że wie i że nie wie
#
# -   uczy się i uczy się uczyć
#
# ### Szukanie wiedzy – problem nadmiaru
#
# 1.  w roku 2007 wyprodukowaliśmy 295 exabajtów ($\approx 10^{18}$
#     bajtów) skompresowanych danych
#
#     -   ok. 60 płyt CD-ROM / osobę
#
#     -   ok. 10 płyt DVD / osobę
#
#     -   ok. 1 twardy dysk (1TB) / 100 osób
#
# 2.  wzrost o:
#
#     1.  6100 $\%$ w stosunku do 1986 r.
#
#     2.  500 $\%$ w stosunku do 2000 r.
#
# 3.  podział na kategorie nośników:
#
#     -   twarde dyski $52\%$
#
#     -   dyski optyczne $28\%$
#
#     -   taśma magnetyczna (zapis cyfrowy) $11\%$
#
#     -   …
#
#     -   papier $0.007\%$
#
# 4.  przeciętny człowiek jest w stanie zapamiętać w sposób trwały w ciągu
#     całego swego życia ok. $200$ megabajtów danych (1 megabajt
#     $\approx 10^{6}$ bajtów).
#
# ### Jak szukać wiedzy?
#
# 1.  Co to jest heksakosjoiheksekontaheksafobia?
#
# 2.  Czym różni się lew od pumy (lwa górskiego)?
#
# 3.  Jacy filozofowie urodzili się w Lublinie?
#
# 4.  Jaki kraj nigdy nie "otrzymał" nagrody Nobla?
#
# 5.  W którym filmie brało udział najwięcej aktorów?
#
# ### Jak szukać wiedzy w internecie – trzy stopnie wtajemniczenia
#
# 1.  <a href="www.wikipedia.com" class="uri">www.wikipedia.com</a>
#
# 2.  <a href="www.wolframalpha.com" class="uri">www.wolframalpha.com</a>
#
# 3.  <http://dbpedia.org>
#
# ### Jak szukać informacji filozoficznej w Internecie?
#
# 1.  <a href="www.wikipedia.com" class="uri">www.wikipedia.com</a>
#
# 2.  *Stanford Encyclopedia of Philosophy*
#     <a href="http://www.science.uva.nl/ seop"
#     class="uri">http://www.science.uva.nl/ seop</a>
#
# 3.  *Powszechna Encyklopedia Filozoficzna* <http://www.ptta.pl/pef/>
#
# ### Jak szukać informacji bibliograficznej?
#
# 1.  bazy danych dostępne w domenie publicznej
#
#     -   dla nauk wszelkich: <http://scholar.google.com>
#
#     -   dla filozofii: *PhilPapers* (<http://philpapers.org/>)
#
#     -   dla informatyki:
#
#         -   *The DBLP Computer Science Bibliography*
#             (<http://www.dblp.org/search>)
#
#         -   *Digitial Library of ACM* (<http://dl.acm.org/>)
#
#     -   dla biologii i medycyny: *PubMed*
#         (<http://www.ncbi.nlm.nih.gov/pubmed/>)
#
# 2.  komercyjne bazy danych (zob. zakładka *Zasoby wiedzy* na e-KUL)
#
#     -   uniwersalne
#
#         -   JSTOR (głównie humanistyka)
#
#         -   EBSCO (głównie nauki społeczne)
#
#         -   ScienceDirect (głównie informatyka i inżynieria)
#
#         -   Scopus (nauki wszelkie)
#
#         -   Web of Knowledge (nauki wszelkie)
#
#         -   …
#
#     -   lokalne
#
#         -   Springer - <a href="www.springerlink.com/journals"
#             class="uri">www.springerlink.com/journals</a>

# %% [markdown]
# ## Co to jest inżynieria ontologii?
#
# **Definicja 2**.
#
# > *Reprezentacja wiedzy jest multidyscyplinarną dziedziną, która stosuje
# > teorie i metody z trzech obszarów:*
# >
# > 1.  *logiki \[która\] określa formalną strukturę \[reprezentacji
# >     wiedzy\] i reguły wnioskowania*
# >
# > 2.  *ontologii \[która\] definiuje rodzaje rzeczy, które istnieją w
# >     dziedzinie zastosowania \[reprezentacji wiedzy\]*
# >
# > 3.  *informatyki (computation) \[która\] wspiera aplikacje
# >     odróżniające reprezentację wiedzy od czystej filozofii*
# >
# > [Sowa, 2000, s. XI-XII]
#
# ### Lokalizacja metodologiczna
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/OE.jpg?raw=1" width="400"/>
#
# ### Reprezentacja?
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/typy-0.png?raw=1" width="400"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/typy.png?raw=1" width="400"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/typ.png?raw=1" width="400"/>
#
# Problem nośnika reprezentacji wiedzy
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/carrier.png?raw=1" width="400"/>
#
#
# ### Terminologia – bliższa
#
# -   *engineering ontology*
#
# -   *ontological engineering*
#
# -   *applied ontology*
#
# ### Terminologia – dalsza
# Zestawienie skonstruowane w trakcie *Ontology Summit 2007*
#
#
#
# |                       |                          |
# |:---------------------:|:------------------------:|
# |       Tag cloud       |         Ontology         |
# | Controlled vocabulary |       Microformats       |
# |       Thesauri        |     Data dictionary      |
# | Collaborative tagging |           OPML           |
# |     Folk taxonomy     |           XOXO           |
# |       Directory       |           OWL            |
# |      Subject Map      |      Subject Trees       |
# |     Semantic Web      | Information Architecture |
# |      Cladistics       |   Data Reference Model   |
# |   Markup languages    |        Phylogeny         |
# |  Social bookmarking   |        Topic Maps        |
# |         Tags          |       Concept Maps       |
# |        Tagging        |         Synsets          |
# |       Taxonomy        |         Glossary         |
# |      Folksonomy       |         Metadata         |
# |    Classification     |          Facets          |
# |    Categorization     |        Structure         |
# |          RDF          |       Dublin Core        |
# |       Metadata        |         Typology         |
# |      Systematics      |         WordNet          |
#
#
# ### Ontologia po raz pierwszy
# Pierwsze użycie słowa ”ontologia”
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/lorhard.jpg?raw=1" width="400"/>
#
#
# ### Ontologia po raz drugi
# Taksonomia ontologii Umbel
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/umbel.png?raw=1" width="800"/>
#
#
#
# ### Dwa źródła inżynierii ontologii
#
# 1.  ontologiczne
#
#     -   koncepcja ontologii W. van O. Quine’a
#
#     -   koncepcja ontologii J. McCarthy’ego
#
# 2.  logiczne
#
# ### Koncepcja ontologii J. McCarthy’ego
#
# -   problem
#
#     > Trzy misjonarze i trzej kanibale mają przeprawić się przez rzekę.
#     > Do dyspozycji jest łódź wiosłowa z dwoma miejscami. Jeżeli liczba
#     > kanibali kiedykolwiek przekroczy liczbę misjonarzy na którymś
#     > brzegu rzeki, misjonarze zostaną zjedzeni. Jak przeprawić się
#     > przez rzekę?
#
# -   <http://www.gry.jeja.pl/2443,kanibale-i-misjonarze.html>
#
# -   problem a golem?
#
# ### Koncepcja ontologii J. McCarthy’ego (2) – reguła ograniczenia
#
# -   reguła ograniczenia (*circumscription rule*) :
#
#     -   Jeżeli z założeń zadania wynika, że jakieś przedmioty istnieją,
#         to przyjmij, że *tylko* te przedmioty istnieją.
#
#     -   Jeżeli z założeń zadania wynika, że jakieś przedmioty posiadają
#         pewną cechę, to przyjmij, że *tylko* te przedmioty posiadają tę
#         cechę.
#
# ### Koncepcja ontologii J. McCarthy’ego (2) – reprezentacja wiedzy
#
# -   Jeżeli chcemy użyć komputera do rozwiązywania, to musimy zapisać w
#     nim założenia tych zadań:
#
#     > Stosowanie ograniczeń wymaga, aby wiedza zdroworozsądkowa była
#     > wyrażona w taki sposób, który głosi, że łódź może przepłynąć rzekę
#     > o ile nic nie uniemożliwia jej użycia. W szczególności, wygląda na
#     > to, że musimy wprowadzić do naszej *ontologii* (\[listy\] rzeczy,
#     > które istnieją) kategorię, która zawiera *łódź \[jest\] popsuta*,
#     > lub kategorię, która zawiera *coś, co może uniemożliwić jej \[tj.
#     > łodzi\] użycie*.
#
# ### Koncepcja ontologii W. van O. Quine’a
#
# > Problem ontologii zdumiewa swoją prostotą. Można go sformułować w
# > dwóch słowach: ,,Co istnieje?”. Co więcej, odpowiedzieć nań można
# > jednym słowem – ,,Wszystko” – i każdy uzna tę odpowiedź za prawdziwą.
# > Jest to jednak tylko stwierdzenie, że istnieje to, co istnieje.
# > Pozostaje więc pole dla różnicy zdań co do poszczególnych przypadków;
# > dlatego właśnie zagadnienie to jest żywe od wielu stuleci. ()
#
# -   zadanie ontologii = sporządzenie listy istniejących
#     przedmiotów/bytów
#
# -   metoda ontologii:
#
#     1.  Znajdź teorię lub teorie, które opisują świat w racjonalny i
#         efektywny sposób, w szczególności dostarczają wydajnych narzędzi
#         porozumiewania się i przewidywania przyszłości!
#
#     2.  Zapisz wyselekcjonowaną teorię (teorie) w w języku logiki!
#
#     3.  Zbiór bytów jest zakresem kwantyfikacji zmiennych w
#         wyselekcjonowanej teorii!
#
# ### Logiczne źródło inżynierii ontologii – manifest tzw. fizyki naiwnej
#
# -   dwa manifesty: oraz
#
# -   Zapiszmy duży fragment wiedzy potocznej (*common-sense knowledge*) o
#     “codziennym” świecie: kolorach, kształtach, przestrzeni, ruchu,
#     czasie, itp. w języku logiki!
#
# -   warunki:
#
#     1.  szeroka $${\textrm{terminy}} \sim 10 000 \div 100 000$$
#
#     2.  gęsta: $$\frac{\textrm{twierdzenia}} {\textrm{terminy}} \gg 1$$
#
#     3.  formalna
#
# ### Logiczne źródło inżynierii ontologii – manifest tzw. fizyki naiwnej (2)
#
# -   przedmiot:
#
#     -   świat widziany przez “przeciętnego” człowieka
#
# -   źródła wiedzy:
#
#     -   intuicja
#
#     -   introspekcja
#
#     -   ankiety, wywiady, itp.
#
# -   podział dziedziny na klastry, np.:
#
#     1.  jakość, ilość, pomiar
#
#     2.  zmiana, czas, historia
#
#     3.  …
#
# ### Dlaczego fizyka naiwna?

# %% [markdown]
# ## Czy maszyna może w ogóle coś wiedzieć?
#
# ### Alan Turing
#
# 1.  brytyjski matematyk i logik
#
# 2.  twórca “angielskiej bomby kryptologicznej” dla rozszyfrowania kodu
#     Enigmy
#
# 3.  specyfikacja komputera Pilot ACE
#
# 4.  maszyna Turinga
#
# 5.  test Turinga ()
#
# ### Maszyna Turinga
#
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/TuringMachine.png?raw=1" width="600"/>
#
# **Definicja 3**. *Maszyna Turinga* jest siódemką
# $<S, s_{0}, Q, L, \emptyset, I, \delta>$:
#
# 1.  *skończony zbiór $S$ możliwych stanów maszyny z wyróżnionym stanem
#     początkowym $s_{0}$ i stanami końcowymi (akceptującymi)
#     $Q \subseteq S$;*
#
# 2.  *skończony zbiór symboli $L$ z symbolem pustym $\emptyset \in L$
#     oraz podzbiorem symboli początkowych $I \subset L$;*
#
# 3.  *funkcja przejścia
#     $\delta: S \times L \to S \times L \times \{\text{w lewo}, \text{stój}, \text{w prawo}\}$.*
#
# <https://turingmachinesimulator.com/>
#
# ### Test Turinga - czy komputer myśli?
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Turing.png?raw=1" width="600"/>
#
# ### Test Turinga - czy komputer myśli? (2)
#
# > Sądzę, że za około 50 lat \[czyli ok. roku 2000 - PG\] będzie możliwe
# > programowania komputerów, z pamięcią rzędu $10^{9}$ \[bitów - PG\],
# > tak aby uczestniczyły w grze \[w chat-zagadkę - PG\] tak dobrze, że
# > przeciętny uczestnik gry nie będzie miał więcej niż 70 procent szans
# > na prawidłową odpowiedź po pięciu minutach rozmowy.
#
# ### Argument chińskiego pokoju
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Chinese-1.png?raw=1" width="600"/>
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Chinese-2.png?raw=1" width="600"/>
#
#
# ### Argument chińskiego pokoju (2) Ponieważ:
#
# 1.  Jeżeli maszyny Turinga myślą, to istnieje maszyna Turinga, której
#     każda implementacja (realizacja) rozumie język chiński.
#
# 2.  Istnieje maszyna Turinga, której żadna implementacja nie rozumie
#     języka chińskiego.
#
# Zatem:
# Maszyny Turinga nie myślą.
#
# ### Argument chińskiego pokoju - wersja uogólniona Ponieważ:
#
# 1.  Maszyny Turinga przetwarzają napisy, tj. znają tylko własności
#     syntaktyczne języka.
#
# 2.  Ludzkie umysły znają znaczenie słów (semantykę/pojęcia).
#
# 3.  Własności syntaktyczne nie określają całkowicie własności
#     semantycznych.
#
# Zatem:
# Ludzkie umysły nie są maszynami Turinga.
#
# ### Czego *nie* dowodzi argument chińskiego pokoju?
#
# 1.  Maszyny nie potrafią myśleć.
#
# 2.  Komputery nie potrafią myśleć.
#
# 3.  Tylko mózgi myślą.
#
# ### Czego dowodzi argument chińskiego pokoju?
#
# 1.  Myślenie nie polega na implementacji (realizacji) maszyny Turinga.
#
# 2.  Nie każdy (odpowiednio zaprogramowany) komputer myśli (= ma umysł).
#
# 3.  Program silnej sztucznej inteligencji (*strong AI*): umysł <span
#     class="alert">jest</span> maszyną Turinga, jest niewykonalny.
#
# 4.  Program słabej sztucznej inteligencji: działanie umysłu można
#     *symulować* za pomocą maszyny Turinga, jest wykonalny.
#
# ### Nagroda Loebnera (1991–…)
#
# 1.  konkurs programów komputerów stworzonych po to, aby zdać test
#     Turinga
#
# 2.  3 medale
#
#     1.  złoty – zdał multimedialny test Turinga
#
#     2.  srebrny – zdał prosty test Turinga
#
#     3.  brązowy – wypadł najlepiej spośród uczestników
#
# 3.  tylko brązowe medale, np. trzykrotnie dla A. L. I. C. E.
#
# 4.  zwycięzca w roku 2017 - Rosette
#     <http://www.aisb.org.uk/events/loebner-prize/>
#
# 5.  Turing nie miał racji
#
# ### Alternatywy dla testu Turinga
#
# 1.  test Feigenbauma () - komputer jako ekspert dziedzinowy
#
# 2.  test minimalnego inteligentnego sygnału - komputer jako binarny
#     człowiek
#
# 3.  test Negroponte - komputer jako pomocnik człowieka
#
# 4.  test Eberta - komputer jako trefniś
#
# Turing odwrócony
#
# ### CAPTCHA - Completely Automated Public Turing test to tell Computers and Humans Apart
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Captcha.jpg?raw=1" width="400"/>
#
# ### Co umie komputer, który myśli?
#
# 1.  rozumuje, rozwiązuje zadania, również w stanie niepewności
#
# 2.  reprezentuje wiedzę
#
# 3.  planuje
#
# 4.  uczy się
#
#     -   uczy się uczyć
#
# 5.  komunikuje się w języku etnicznym
#
# 6.  integruje w/w umiejętności w ramach strategii dążącej do osiągnięcia
#     pewnego celu
#
# ### Reprezentacja wiedzy
#
# -   problem: jak zapisać **wiedzę** w komputerze, aby:
#
#     1.  maszyna umiała *generować* nową wiedzę z wiedzy powierzonej
#
#         -   rozumować/wnioskować
#
#         -   rozwiązywać problemy
#
#         -   …
#
#     2.  ludzie *rozumieli* (nową i powierzoną) wiedzę
#
#     3.  maszyna umiała *dzielić się* wiedzą z innymi maszynami
#
# ### Problem semantyczny reprezentacji wiedzy
#
# 1.  problemy ze **znaczeniem** (**sensem**)
#
#     1.  Warszawa jest stolicą Polski.
#
#     2.  Warszawa jest stolicą Polski.
#
#     3.  Stolicą Polski jest Warszawa.
#
#     4.  Warszawa jest siedzibą rządu Polski.
#
#     5.  sdfe@@!!¿¡,. ssssssą ¿?¿?¿?.
#
# 2.  problemy z **wnioskowaniem**
#
#     -   Warszawa jest stolicą Polski.
#
#     -   Warszawa jest miastem.

# %% [markdown]
# ## Oldskulowe sposoby reprezentacji wiedzy
#
# ### Wiedza w tekście
#
# Wiedza jako tekst
#
# Ten tekst/napis jest reprezentowany w komputerze.
#
# 1.  problem wieży Babel
#
#     -   Zażółć gęślą jaźń.
#
#     -   standard *Unicode*
#         (<a href="www.unicode.com" class="uri">www.unicode.com</a>)
#
#         -   ponad 1 000 000 (abstrakcyjnych) znaków
#
#         -   ponad 90 systemów pisma (np. alfabetyczne, piktograficzne,
#             ideograficzne, itd.)
#
# 2.  problemy ze znaczeniem
#
#     1.  Warszawa jest stolicą Polski
#
#     2.  Warszawa jest stolicą Polski
#
#     3.  Stolicą Polski jest Warszawa
#
#     4.  Warszawa jest siedzibą rządu Polski
#
#     5.  sdfe@@!!¿¡,.
#
# 3.  problemy z wnioskowaniem
#
# ### Rozwiązania problemu semantycznego
#
# 1.  wersja mini - semantyka w metadanych
#
# 2.  …
#
# 3.  wersja maxi - semantyka w logice
#
#     -   ontologia stosowana
#
# ### Wiedza odziana w metadane
#
# -   dane o danych
#
# -   metadane dla reprezentacji wiedzy (nie-potocznej):
#
#     1.  MARC standard
#
# -   XML jako alfabet metadanych=znaczników
#
#     -   *e**x**tensible **m**arkup **l**anguage*
#
#     -   język znaczników (*tags*) = metajęzyk
#
#     -   schemat XML definiuje układ znaczników
#
# -   przykład
# ```
#     <capital_cities\_data>
#     <item>
#     <city>**Warszawa**</city>
#     <country>**Polska**</country>
#     </item>
#     </geographic\_data>
# ```
#
# ### Wiedza w metadanych - <a href="schema.org" class="uri">schema.org</a>
#
# -   drzewo znaczników HTML (*HTML tags*), które są/będą wykorzystywane
#     przez Google, Yahoo! oraz Bing do wyszukiwania informacji
#
# -   część standardu HTML5
#
# -   typ mikrodanych
#
# <a href="schema.org" class="uri">schema.org</a> (2)
#
# Restauracja “MAGIA”
# 20-114 Lublin
# ul. Rybna 1 / Grodzka 2
# **RESTAURACJA: kontakt, rezerwacje:** tel. +48 (81) 5323041
#
# HTML
# ```
# <p align=”center”> Restauracja &quot;MAGIA&quot; </p> <br>
# 20-114 Lublin<br>
# ul. Rybna 1 / Grodzka 2 <br>
# <p align=”center”> <br>
# <b> &nbsp;&nbsp;&nbsp;RESTAURACJA: kontakt, rezerwacje </b> <br>
# tel. +48 (81) 532304 </p>
# ```
#
# schema.org
# ```
# <p align=”center”>
# <div itemscope itemtype=”http://schema.org/Restaurant”>
# <span itemprop=”name”>Restauracja &quot;MAGIA&quot; </span> </p> <br>
# <div itemprop=”address” itemscope itemtype=”http://schema.org/PostalAddress”> <br> <span itemprop=”postalCode”> 20-114 Lublin</span> <br>
# <span itemprop=”streetAddress”>ul. Rybna 1 / Grodzka 2</span>
# </div>
# <p align=”center”> <br>
# <b> &nbsp;&nbsp;&nbsp;RESTAURACJA: kontakt, rezerwacje </b> <br>
# <span itemprop=”telephone”>+48 (81) 532304</span>
# </p> </div>
# ```
#
# ### Jak reprezentuje wiedzę *A.L.I.C.E.*?
#
# -   *Artificial Linguistic Internet Computer Entity* -
#     <a href="www.alicebot.org" class="uri">www.alicebot.org</a>
#
# -   trzykrotny zwycięzca brązowego medalu nagrody Loebnera
#
# -   metadane dla pytań i odpowiedzi w języku AIML
#
# ### Jak reprezentuje wiedzę *A.L.I.C.E.*? (2)
#
# ```
# <category><pattern>HOW FAR IS ALPHA CENTAURI</pattern><template>Four light
# years.</template></category>
#
# <category><pattern>HOW MANY LITERS CUP</pattern><template>236.6
# milliliters</template></category>
#
# <category><pattern>WHERE IS BANGLADESH</pattern><template> <set name=”it”> <set name=”topic”> BANGLADESH </set> </set> is part of the Indian subcontinent, on the eastern side.</template></category>
# ```
#
# -   wiedza skompresowana:
#
# ```
# <category><pattern>IS GOD REAL</pattern><template><srai>DOES GOD EXIST</srai></template></category>
#
# <category><pattern>DOES GOD EXIST</pattern><template> <srai>DO YOU BELIEVE IN GOD</srai> </template></category>
#
# <category><pattern>DO YOU BELIEVE IN GOD</pattern><template>Of course I believe in God, <get name=”name”/>.</template></category>
# ```
#
# ### Wiedz w bazie danych
#
# Wiedza w relacyjnej bazie danych
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/DB1.png?raw=1" width="600"/>
#
# Wiedza w relacyjnej bazie danych (2)
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/DB2.png?raw=1" width="600"/>
#
#
# ### Relacyjny model danych
#
# -
#
#     -   tabelka jako relacja
#
#     -   wiersz tabelki/rekord jako $n$-tka uporządkowana
#
#     -   baza danych jako struktura relacyjna
#
#     -   relacje w logice
#
#         1.  kolejność argumentów jest istotna
#
#         2.  argumenty relacji nie muszą mieć nazw/identyfikatorów
#
#     -   relacje w relacyjnym modelu danych
#
#         1.  kolejność argumentów nie jest/nie musi być istotna
#
#         2.  argumenty relacji muszą mieć nazwy/identyfikatory
#
# -    - baza danych jako język pierwszego rzędu ($\mathbb{WRP}$)
#
# ### Wiedza na rysunkach (JDD)
#
# ### UML - język reprezentacji wiedzy w *inżynierii oprogramowania*
#
# Defincja UML
#
# > Zunifikowany język modelowania (UML) jest graficznym językiem do
# > wizualizacji, specyfikacji, tworzenia i dokumentowania wytworów
# > systemu wykorzystującego oprogramowanie (*the artifacts of a
# > software-intensive system*). UML oferuje standardowy sposób pisania
# > projektu systemu, włączając w to zarówno aspekt pojęciowy obejmujący
# > procesy biznesowe i funkcje systemu jak i aspekt konkretny, np.
# > komendy języka programowania, schematy baz danych i komponenty systemu
# > nadające się do wielokrotnego użytku.
#
# (za: specyfikacją UML przygotowaną przez konsorcjum OMG
# <http://www.uml.org>)
#
# ### Typy diagramów UML
#
# 1.  diagramy strukturalne
#
#     -   diagramy klas
#
#     -   diagramy komponentów
#
#     -   diagramy implementacji
#
# 2.  diagramy dynamiczne
#
#     -   diagramy przypadków użycia
#
#     -   diagramy stanów
#
#     -   diagramy aktywności
#
# 3.  diagramy interakcji
#
#     -   diagramy komunikacji
#
#     -   diagramy sekwencji
#
#     -   diagramy czasowe
#
# ### Przykłady diagramów klas
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/tabelka.jpg?raw=1" width="400"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/subsumpcja.jpg?raw=1" width="400"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/egzemplifikacja.jpg?raw=1" width="150"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/relacje.jpg?raw=1" width="500"/>
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/mereologia.jpg?raw=1" width="400"/>
#
#
#
#
#
#
# ### Serializacja diagramów UML
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/xmi.jpg?raw=1" width="900"/>
#
# UML jako meta-UML
#
# <img src="https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/metaUML.jpg?raw=1" width="900"/>

# %% [markdown]
# ## Matka jest tylko jedna, czyli ontologia filozoficzna
#
# ### Ontologia po raz pierwszy
#
# ![Strona tytułowa *Ogdoas Scholastica* Jakoba Lorharda (pobrana z
# <a href="www.ontology.co" class="uri">www.ontology.co</a>)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/lorhard.jpg?raw=1)
#
# "Pierwsza" definicja ontologii
#
# > \[Ontologia jest\] nauką o tym, co poznawalne jako poznawalne, o ile
# > tylko jest poznawalne przez człowieka za pomocą przyrodzonego światła
# > rozumu bez jakiegokolwiek pojęcia materii \[…\].
#
# Pierwsza definicja ontologii
#
# > Jest taka wiedza, która rozważa byt jako byt oraz to, co przysługuje
# > mu w sposób istotny (Arystoteles, *Metafizyka* 1003a 20)
#
# $\tau \alpha  \mu \eta \tau \alpha   \tau \alpha  \phi \upsilon  \sigma \iota \kappa \alpha$
#
# Lorharda klasyfikacja bytów $$\label{equ:lorhard}
# \text{[byt]} \left\{
# \begin{array}{ll}
# \text{uniwersalny} & \left\{\begin{array}{ll} \text{ogólny} \left\{\begin{array}{ll} \text{nicość} & \\ \text{coś} & \\ \end{array} \right. \\ & \\ \text{wspólne własności} & \\ \end{array} \right. \\
# \text{konkretny} & \left\{\begin{array}{ll} \text{substancje\index{substancja}} & \\ \text{przypadłości} & \\ \end{array} \right. \\
# \end{array} \right.$$
#
# Lorharda klasyfikacja bytów (2)
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/lorhardTax.jpg?raw=1)
#
# ### Gottfried W. Leibniz
#
# ![Gottfried W. Leibniz (1646-1716)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Leibniz.jpg?raw=1)
#
# G. W. Leibniza koncepcja substancji
#
# > \[…\] a) substancja jest bytem mającym wewnętrzną tendencję działania,
# > rozwoju, jest stałym centrum zmian
# > b) substancja jest podmiotem, czyli bytem, który nie tkwi w czymś
# > innym, lecz jest podłożem wielu różnych cech i czynnikiem ich
# > spójności
# > c) substancja jest bytem zupełnym, scharakteryzowanym w każdym
# > aspekcie
# > d) substancja jest prawdziwą jednością, tj. bytem prostym,
# > niezłożonym.
#
# G. W. Leibniza koncepcja substancji (2)
#
# -   "monady nie mają okien"
#
# -   harmonia przedustawna
#
# -   zasadnie nieodróżnialności Leibniza: dwie substancje posiadają różne
#     własności
#
#     $x = y$
#     wtedy i tylko wtedy gdy
#     każda własność $x$ jest własnością $y$ i *vice versa*.
#
# Zasad racji dostatecznej
#
# Wszystko ma swoją przyczynę.
#
# Idea *characteristica universalis*
#
# 1.  Identyfikujemy pojęcia pierwotne, tj. takie, które, z jednej strony,
#     posłużą nam do zdefiniowania pozostałych pojęć, a które, z drugiej
#     strony, same nie są już dalej definiowalne.
#
# 2.  Identyfikujemy prawidłowości (reguły), które łączą pojęcia pierwotne
#     ze sobą w taki sposób, że powstają pojęcia złożone.
#
# 3.  Zastępujemy pojęcia pierwotne symbolami liczb (pierwszych).
#
# 4.  Zastępujemy prawidłowości gramatyczne operacjami matematycznymi.
#
# 5.  (Aby odkryć lub udowodnić jakąś prawdę) *liczymy*.
#
# Christian Wolff
#
# ![Christian Wolff (1679-1754)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Wolff.jpg?raw=1)
#
# ### Koncepcja bytu Ch. Wolffa
#
# -   Bytem jest to, co *może* istnieć, czyli to, czego istota istota nie
#     jest sprzeczna.
#
# -   ogólne własności bytu (*affectiones*):
#
#     1.  istota
#
#     2.  egzystencja
#
#     3.  atrybut
#
#     4.  sposób (*modus*)
#
#     5.  konieczność
#
#     6.  przygodność
#
#     7.  miejsce
#
#     8.  czas
#
#     9.  doskonałość
#
#     10. porządek
#
#     11. prostota
#
#     12. złożenie
#
#     13. inne własności
#
# Fazy rozwoju ontologii filozoficznej
#
# 1.  ontologia naturalna (*naturalis*)
#
# 2.  ontologia sztuczna (*artificialis*)
#
# ### Bernard Bolzano
#
# ![Bernard Bolzano (1781-1848)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Bolzano.jpg?raw=1)
#
# Taksonomia bytów B. Bolzany
#
# 1.  byty rzeczywiste
#
#     1.  substancje
#
#     2.  przypadłości
#
# 2.  byty nierzeczywiste
#
#     1.  przedstawienia same w sobie
#
#     2.  sądy same w sobie
#
# Koncepcja bytów nierzeczywistych B. Bolzano
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/BolzanoIdee.jpg?raw=1)
#
# ### Edmund Husserl
#
# ![Edmund Husserl (1859-1938)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Husserl.jpg?raw=1)
#
# Podział ontologii E. Husserla
#
# 1.  ontologia materialna
#
#     1.  natura
#
#     2.  świadomość
#
#     3.  kultura (*Geist*)
#
# 2.  ontologia formalna
#
# Fundamentalne kategorie ontologii formalnej
#
# 1.  przedmioty indywidualne
#
# 2.  gatunki, własności i relacje
#
# 3.  relacja zależności, np.
#
#     -   zależność pomiędzy jednym a drugim biegunem magnesu
#
#     -   zależność pomiędzy przedmiotem (niższego rzędu) a nadbudowaną
#         nad nim całością (wyższego rzędu), np. pomiędzy poszczególnymi
#         słowami zdania a samym zdaniem
#
#     -   zależność pomiędzy pytaniem a udzieloną odpowiedzią.
#
# 4.  stany rzeczy
#
# 5.  relacja części-całość
#
# 6.  …
#
# ### Roman Ingarden
#
# ![Roman Ingarden (1893-1970)](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Ingarden.jpg?raw=1)
#
# Ingardenowska definicja ontologii
#
# > Ontologia \[…\] to nauka aprioryczna (tzn. epistemologicznie
# > niezależna od spostrzeżenia zewnętrznego czy wewnętrznego, oparta na
# > doświadczeniu ejdetycznym), która w intuitywnej (intelektualnej)
# > analizie zawartości idei odkrywa i ustala czyste możliwości i związki
# > konieczne pomiędzy czystymi jakościami idealnymi.
#
# > Metafizyka jest \[…\] nauką o stanach koniecznościowych zachodzących w
# > obrębie tego, co faktycznie istniejące, nauką o istocie tego, co
# > faktycznie istnieje.
#
# Działy ontologii w/g R. Ingardena
#
# 1.  ontologia egzystencjalna
#
# 2.  ontologia formalna
#
# 3.  ontologia materialna
#
# Aspekty bytu
#
# > Każdy przedmiot (coś w ogóle) może być rozważany \[...\] pod trzema
# > różnymi właściwymi mu względami: (1) co do swego istnienia i sposobu
# > istnienia, (2) co do swej formy \[struktury\], (3) co do swego
# > materialnego \[jakościowego\] uposażenia.
#
# Aspekty egzystencjalny
#
# > W sprawach egzystencjalnych należy rozróżnić dwa zasadniczo odmienne
# > pytania: (a) czy pewien przedmiot x w jakimkolwiek sensie we właściwy
# > mu sposób faktycznie istnieje \[a więc przedmiot może faktycznie nie
# > istnieć i (b) jakiego rodzaju jest sposób istnienia przedmiotu x,
# > wyznaczony przez jego istotę.
#
# Sposoby istnienia – definicja
#
# > Najpierw ustalmy myślowo własności \[…\] pewnej nie istniejącej lampy
# > i przeciwstawmy ją lampie dokładnie takiej samej co do wszystkich jej
# > własności \[…\], ale już istniejącej. \[…\] co musi się niejako
# > ,,dołączyć” do owej nie istniejącej lampy, żeby istniała, co odróżnia
# > ją od lampy istniejącej? \[…\] Otóż ogół tego, co ją w ten sposób od
# > nie istniejącej ,,lampy” różni, nazywam jej sposobem istnienia.
#
# Podstawowe sposoby istnienia
#
# 1.  istnienie absolutne
#
# 2.  istnienie idealne
#
# 3.  istnienie realne
#
# 4.  istnienie intencjonalne
#
# Momenty istnienia
#
# 1.  samoistność – niesamoistność
#
# 2.  pierwotność – pochodność
#
# 3.  samodzielność – niesamodzielność
#
# 4.  niezależność – zależność
#
# Samoistność vs niesamoistność
#
# > Coś istnieje samoistnie (jest bytowo autonomiczne), jeżeli ma samo w
# > sobie swój fundament bytowy. Ma zaś w sobie taki fundament, jeżeli
# > samo w sobie jest immanetnie określone. Coś natomiast istnieje
# > niesamoistnie (jest bytowo heteronomiczne), jeżeli swój bytowy
# > fundament ma nie w sobie samym, ale w czymś innym.
#
# Pierwotność – pochodność
#
# > Przedmiot jest bytowo pierwotny, jeżeli z istoty swej nie może być
# > wytworzony przez żaden inny przedmiot. \[…\] Przedmiot jest natomiast
# > bytowo pochodny, jeżeli w swej istocie jest taki, że istnieć może
# > tylko z wytworzenia przez inny przedmiot.
#
# Samodzielność – niesamodzielność
#
# > Przedmiot istnieje samodzielnie, jeżeli nie wymaga z istoty swej
# > istnienia żadnego innego przedmiotu, z którym musiałby współistnieć w
# > obrębie jednej i tej samej całości. \[…\] Natomiast coś jest bytowo
# > niesamodzielne, jeżeli istnienie jego jest z jego istoty koniecznym
# > współistnieniem w obrębie jednej całości z czymś innym \[…\].
#
# Niezależność – zależność
#
# > Jest \[…\[ możliwe, że pewien przedmiot jest bytowo samodzielny, a
# > pomimo to z istoty swej wymaga dla swego istnienia jakiegoś innego
# > przedmiotu bytowo samodzielnego. Mówimy wtedy o nim, że jest od niego
# > bytowo zależny. \[…\] Gdy natomiast pewien bytowo samodzielny
# > przedmiot nie wymaga z istoty swej dla swego istnienia żadnego bytowo
# > samodzielnego, a tym samym żadnego w ogóle innego przedmiotu, wówczas
# > jest w sensie absolutnym bytowo niezależny.

# %% [markdown]
# ## Ontologie w informatyce
#
# Definicja ontologii (w sensie inżynierii ontologii)
#
# **Definicja 4**. *Ontologia jest formalną, jawną specyfikacją
# współdzielonej konceptualizacji. *
#
# ### Potrzeba analizy ontologicznej - przykład pierwszy
#
# | **ACFT** | **Type** |
# |:--------:|:--------:|
# | N7213US  |   B747   |
# | N3821US  |   B777   |
# | N4452US  |   A320   |
# |    …     |    …     |
#
# Tabela *Resources* z *DB United Airlines*
#
# | **Model** | **Facility** |
# |:---------:|:------------:|
# |    717    |    Renton    |
# |    747    |   Everett    |
# |    777    |   Everett    |
# |     …     |      …       |
#
# Tabela *Production* z *DB Boeing Corporation*
#
# | **Tail** | **PurchaseDate** |
# |:--------:|:----------------:|
# | N4213US  |    1998.02.12    |
# | N3801US  |    1999.04.12    |
# | N7252US  |    2004.05.02    |
# |    …     |        …         |
#
# Tabela *777* z *DB US Airways*
#
# ### Potrzeba analizy ontologicznej - przykład pierwszy (2)
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/DB1.jpg?raw=1)
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/DB2.jpg?raw=1)
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/DB3.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi
#
# 1.  projekt J-TADIS
#
#     1.  integracja różnych systemów zarządzania i kontroli obrony
#         powietrznej (*Air Defence Control and Command legacy systems*)
#
#     2.  usługodawca: Ministerstwo Obrony Zjednoczonego Królestwa
#
#     3.  usługobiorca: Qinetiq
#         (<a href="www.qinetiq.co.uk" class="uri">www.qinetiq.co.uk</a>)
#
# 2.  wiadomości ACO (*Air Command Order*)
#
#     1.  …
#
#     2.  ACM - *Air Control Means*
#
#     3.  …
#
# ### Potrzeba analizy ontologicznej - przykład drugi (2)
#
# ![Architektura systemu JTADIS ](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/JTADIS.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (3)
#
# ![Idea modułu SIE ](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/SIE.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (4)
#
# ![Struktura ACM typu CIRCLE](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/ACM.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (5) …
# ACMID/ACM:ROZ/NAME:ROZ1/CIRCLE/LATS:240115N0555342E/15.0KM//
# EFFLEVEL/FLFL:FL150-FL350//
# …
#
# ### Potrzeba analizy ontologicznej - przykład drugi (6)
#
# ![ACM “ROZ1”](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/ACM_Ex.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (7)
#
# ![Interpretacja ontologiczna ROZ1](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/ACM_Int_1.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (8)
#
# ![Interpretacja ontologiczna ROZ1](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/ACM_Int_2.jpg?raw=1)
#
# ### Potrzeba analizy ontologicznej - przykład drugi (9)
#
# ![Interpretacja ontologiczna ROZ1](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/ACM_Int_3.jpg?raw=1)

# %% [markdown]
# ## Inżynieria ontologii – skok na bungee
#
# ### Ontologia wczoraj …
#
# -   *Jest taka wiedza, która rozważa byt jako byt oraz to, co
#     przysługuje mu w sposób istotny* (Arysototeles, *Metafizyka* 1003a
#     20)
#
# -   $\tau \alpha  \mu \eta \tau \alpha   \tau \alpha  \phi \upsilon  \sigma \iota \kappa \alpha$
#
# -   J. Lorhard *Ogdoas Scholastica, continens Diagraphen Typicam artium:
#     Grammatices (Latinae, Graecae), Logices, Rhetorices, Astronomices,
#     Ethices, Physices, Metaphysices, seu Ontologiae*
#
# -   (nic) o wszystkim:
#
#     -   Nic nie może jenocześnie być jakieś i nie być jakieś.
#
#     -   Każdy byt ma swoją przyczynę.
#
#     -   W rzeczywistości nie istnieją przedmioty ogólne.
#
#     -   …
#
# -   ontologie formalne:
#
#     -   ontologia S. Leśniewskiego
#
#     -   system H. Scholza
#
#     -   metafizyka obliczeniowa E. Zalty
#
# ### …i ontologia dziś
#
# -   inżynieria ontologiczna/ontologii –dziedzina nauki/inżynierii
#
#     -   informatyka
#
#     -   sztuczna inteligencja
#
#     -   reprezentacja wiedzy
#
# -   ontologie inżynieryjne - artefakty wyprodukowane i opisywane w
#     inżynierii ontologii
#
#     -   <http://swoogle.umbc.edu>
#
#     -   $>$<!-- -->10 000 ontologii (w 2007 roku)!
#
#         -   $>$<!-- -->100 000 unikalnych dokumentów semantycznych w
#             języku RDF(S)
#
# ### …i ontologia dziś (2)
#
# 1.  wymiar instytucjonalny
#
#     1.  *International Association for Ontology and its Applications*
#         (<a href="www.iaoa.org" class="uri">www.iaoa.org</a>)
#
#     2.  *Institute for Formal Ontology and Medical Information Science*
#         (<a href="ifomis.org" class="uri">ifomis.org</a>)
#
#     3.  *Knowledge Media Institute*
#         (<a href="www.kmi.open.ac.uk" class="uri">www.kmi.open.ac.uk</a>)
#
#     4.  *National Center For Biomedical Ontology*
#         (<a href="www.bioontology.org" class="uri">www.bioontology.org</a>)
#
#     5.  *Information Systems Laboratory*
#         (<a href="www.ics.forth.gr" class="uri">www.ics.forth.gr</a>)
#
#     6.  …
#
# 2.  publikatory
#
#     1.  *Applied Ontology*
#
#     2.  *Data and Knowledge Engineering*
#
#     3.  *International Journal of Human and Computer Studies*
#
#     4.  konferencje:
#
#         1.  *Formal Ontology in Information Systems*
#
#         2.  *Formal Ontologies Meet Industry*
#
#         3.  *Knowledge Representation and Reasoning*
#
#         4.  …
#
# ### …i ontologia dziś (3)
#
# 1.  ontologiczny sektor IT
#
#     -   Apple SIRI
#
#     -   BeInformed
#
#     -   Cambridge Semantics
#
#     -   Connotate
#
#     -   Department of Homeland Security
#
#     -   EDM Council
#
#     -   Franz \| AMDOCS
#
#     -   IBM Dr. Watson Project
#
#     -   Innovative Query
#
#     -   Mayo Clinic
#
#     -   Recognos Financial
#
#     -   Revelytix
#
#     -   Sallie Mae
#
#     -   Sandpiper
#
#     -   Semantic Arts
#
#     -   Top Quadrant
#
#     -   Trigent Software
#
#     -   Visual Knowledge
#
#     -   zAgile
#
# 2.  ontologiczny sektor IT w Polsce
#
#     -   MakoLab <https://makolab.com>
#
#     -   Cognitum <http://www.cognitum.eu>
#
#     -   Rodan Systems
#
# ### …i ontologia dziś (4)
#
# 1.  Ontologia stosowana mówi wielu językami
#
#     -   KIF
#
#     -   Ontolingua
#
#     -   Express
#
#     -   DAML+OIL
#
#     -   RDF i RDF(S)
#
#     -   OWL - obecnie OWL 2.0
#
#     -   Common Logic
#
#     -   język naturalny
#
# ### …i ontologia dziś (5)
#
# 1.  edytory “graficzne” do tworzenia i walidacji ontologii
#
#     -   Altova SemanticWorks
#
#     -   FluentEditor
#
#     -   HOZO
#
#     -   Protege
#
#     -   TopBraid
#
# 2.  środowiska programistyczne
#
#     -   JENA
#         (<a href="jena.sourceforge.net" class="uri">jena.sourceforge.net</a>)
#
#     -   OwlDotNetApi
#
#     -   SETH
#
# 3.  automatyczne rozumowanie w ontologii
#
#     -   rozmaite wtyczki (*plugin*) do Protege
#
#
# ### 10 000+ ontologii inżynieryjnych w 40 słowach
#
# |                       |                          |
# |:---------------------:|:------------------------:|
# |       Tag cloud       |         Ontology         |
# | Controlled vocabulary |       Microformats       |
# |       Thesauri        |     Data dictionary      |
# | Collaborative tagging |           OPML           |
# |     Folk taxonomy     |           XOXO           |
# |       Directory       |           OWL            |
# |      Subject Map      |      Subject Trees       |
# |     Semantic Web      | Information Architecture |
# |      Cladistics       |   Data Reference Model   |
# |   Markup languages    |        Phylogeny         |
# |  Social bookmarking   |        Topic Maps        |
# |         Tags          |       Concept Maps       |
# |        Tagging        |         Synsets          |
# |       Taxonomy        |         Glossary         |
# |      Folksonomy       |         Metadata         |
# |    Classification     |          Facets          |
# |    Categorization     |        Structure         |
# |          RDF          |       Dublin Core        |
# |       Metadata        |         Typology         |
# |      Systematics      |         WordNet          |
#
# Zestawienie skonstruowane w trakcie *Ontology Summit 2007*
#
# ### Sieć Semantyczna a ontologia inżynieryjna
#
# > Sieć Semantyczna nie jest osobną siecią, lecz rozszerzeniem obecnej, w
# > którym informacja posiada dobrze zdefiniowane znaczenie, co zwiększa
# > możliwości komputerów i ludzi do współpracy. \[…\] maszyny będą lepiej
# > przetwarzać i ,,rozumieć” te dane, które obecnie tylko wyświetlają.
# > \[…\] Aby Sieć Semantyczna mogła funkcjonować, komputery muszą mieć
# > dostęp do ustrukturyzowanych zasobów danych oraz zbiorów reguł
# > wnioskowania, których będą mogły użyć do procesów automatycznego
# > wnioskowania.
#
# ### Sieć Semantyczna a ontologia inżynieryjna (2)
#
# ![Rysunek z ](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/SemanticWeb.jpg?raw=1)
#
# Spektrum ontologii inżynieryjnych
#
# ![Diagram L. Obrsta z Mitre Corporation z
# <a href="www.mkbergman.com" class="uri">www.mkbergman.com</a>](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/SS.jpg?raw=1)
#
# ### Typologia ontologii inżynieryjnych
#
# 1.  ontologie terminologiczne:
#
#     1.  kontrolowane słowniki
#
#     2.  glosariusze
#
#     3.  systemy klasyfikacji
#
#     4.  tezaurusy
#
# 2.  ontologie informacyjne:
#
#     1.  luźne struktury subsumpcyjne oraz
#
#     2.  zwykłe i wzbogacone taksonomie
#
# 3.  ontologie modelowania wiedzy:
#
#     1.  ontologie oparte na tzw. ,,ramkach”
#
#     2.  ontologie umożliwiające definiowanie relacji
#
#     3.  ontologie umożliwiające definiowanie relacji między kategoriami
#         oraz własności relacji
#
#     4.  ontologie jako (pełne) teorie aksjomatyczne
#
# ### Ontologia wczoraj a ontologia dziś
#
# |      **Filozofia**       |          **Informatyka**          |
# |:------------------------:|:---------------------------------:|
# |     języki etniczne      |          języki formalne          |
# |          teorie          |      artefakty epistemiczne       |
# |    wiedza dla wiedzy     | komponent systemu informatycznego |
# | pluralizm metodologiczny |     pluralizm metodologiczny      |
# | najczęściej: o wszystkim |       czasami: o wszystkim        |
# | najczęściej: jeden autor |    najczęściej: wielu autorów     |
# | im dziwniej, tym weselej |        prostota, głupcze!         |

# %% [markdown]
# ## Inżynieria ontologii – grzybobranie
#
# ### Cyc
#
# Wiedza w ontologii Cyc
#
# -   baza wiedzy zdroworozsądkowej (*common-sense knowledge*)
#
#     -   teoria aksjomatyczna
#
#     -   język logiki drugiego rzędu (oparty na notacji języka LISP)
#
#     -   prawie 500 000 terminów/słów
#
#     -   około 15 000 relacji
#
#     -   ponad 7 000 000 aksjomatów
#
# -   “silnik” wnioskujący
#
# -   moduł przetwarzania języka etnicznego
#
# Cyc jako produkt
#
# -   D. Lenat, R. Guha i in.
#
# -   Cycorp - <a href="www.cyc.com" class="uri">www.cyc.com</a>
#
# -   zastosowania
#
#     1.  informatyka medyczna
#
#     2.  analiza finansowa
#
#     3.  bezpieczeństwo systemów komputerowych
#
#     4.  …
#
# -   wersje Cyc:
#
#     -   OpenCyc
#
#     -   ResearchCyc
#
#     -   EnterpriseCyc
#
# Struktura bazy wiedzy Cyc
#
# -   dwie relacje teoriomnogościowe
#
#     1.  isa - $\in$
#
#         -   `#$isa #$Lublin #$City`
#
#     2.  genls - $\subset$
#
#         -   `#$genls #$City #$GeographicalRegion`
#
# -   mikroteorie
#
#     -   reprezentacja kontekstu
#
#     -   przynajmniej jedna mikroteoria dla każdego stwierdzenia
#
#     -   relacja bardziej-mniej ogólna
#
#     -   mikroteorie mogą być sprzeczne!
#
# Rzut oka na strukturę Cyc
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/kbase.png?raw=1)
#
# “Góra” mikroteorii BaseKB
#
# ![Kategorie ontologiczne Cyc](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Cyc.jpg?raw=1)
#
# Co OpenCyc wie o Lublinie?
#
# ![Co to jest Lublin?](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/Lublin.jpg?raw=1)
#
# <http://umbel.org/> [Otwórz graf wiedzy UMBEL](run:umbel.pdf)
#
# ### DOLCE
#
# DOLCE – ontologia kognitywna
#
# -   *Descriptive Ontology for Linguistic and Cognitive Engineering*
#
# -   Laboratory for Applied Ontology (LOA) –
#     <http://www.loa.istc.cnr.it/old/DOLCE.html>
#
# -   metodologia OntoClean
#
# -   wersja “oficjalna”
#
#     -   węższy rachunek predykatów z identycznością, rozszerzony o język
#         logiki modalnej
#
#     -   ok. 80 aksjomatów i kilkaset definicji pomocniczych
#
# -   wersja OWL
#
# DOLCE – ontologia kognitywna (2)
#
# -   kategorie specyficzne dla zdroworozsądkowego sposobu postrzegania
#     otaczającej nas rzeczywistości, które znalazły swoje
#     odzwierciedlenie w postaci słów i wyrażeń języka potocznego
#
# -   inspirowana kognitywistyką, m. in. teorią przestrzeni pojęciowych P.
#     Gardenforsa, oraz badaniami lingwistycznymi, m. in. klasyfikacją
#     czasowników Z. Vendlera
#
# -   ponad czterdzieści kategorii (klas przedmiotów) oraz ponad sto
#     relacji
#
# DOLCE – *helicopter view*
#
# <figure>
# <embed src="img/dolce-eps-converted-to.pdf" id="fig:dolce" />
# <figcaption aria-hidden="true">Taksonomia DOLCE</figcaption>
# </figure>
#
# Filozoficzne założenia DOLCE
#
# -   Zachodzi różnica ontologiczna pomiędzy bytami uniwersalnymi i
#     konkretnymi.
#
# -   DOLCE jest ontologią bytów konkretnych (kategoria PT), które są
#     klasyfikowane za pomocą kategorii uniwersalnych, z których zbudowana
#     jest ta ontologia.
#
# -   Zachodzi ontologiczna różnica pomiędzy bytami abstrakcyjnymi, tj.
#     istniejącymi poza czasem i przestrzenią, należącymi do kategorii AB,
#     a bytami konkretnymi, istniejącymi przynajmniej w czasie.
#
# -   Zachodzi ontologiczna różnica pomiędzy bytami *trwającymi* w czasie
#     i obecnymi ,,w całości” w każdej chwili swojego istnienia,
#     należącymi do kategorii ED, a bytami *zmieniającymi się* w czasie,
#     posiadającymi w różnych chwilach swojego istnienia osobne fazy
#     (części czasowe), należącymi do kategorii PD.
#
# Filozoficzne założenia DOLCE (2)
#
# -   Zachodzi ontologiczna różnica pomiędzy własnościami konkretnymi,
#     które można obserwować lub mierzyć, należącymi do kategorii Q, a
#     abstrakcyjnymi ,,wartościami” tych własności (*quale*) należącymi do
#     kategorii regionów R, która jest podkategorią kategorii AB.
#
# -   Dwa lub więcej różnych przedmiotów materialnych może zajmować tę
#     samą przestrzeń w tym samym, czasie.
#
# -   Istnieją byty przeszłe, teraźniejsze i przyszłe (eternalizm).
#
# Najważniejsze relacje w DOLCE
#
# -   partycypacja (*participation*) – jest to relacja trójargumentowa,
#     której pierwszym argumentem mogą być elementy klasy ED, drugim
#     argumentem elementy klasy PD, zaś trzecim czas.
#
# -   konstytucja (*constitution*) – jest to relacja trójargumentowa,
#     której pierwszym argumentem mogą być elementy klasy ED lub PD,
#     drugim argumentem elementy klasy ED lub PD, zaś trzecim czas.
#
# -   bycie częścią (*parthood*) – jest to relacja dwuargumentowa, której
#     argumentami mogą być elementy klasy AB lub PD.
#
# Najważniejsze relacje w DOLCE (2)
#
# -   czasowe bycie częścią (*temporary parthood*) – jest to relacja
#     trójargumentowa, której pierwszym argumentem mogą być elementy klasy
#     ED, drugim argumentem elementy klasy PD, zaś trzecim czas
#
# -   bycie własnością (*quality*) – jest to relacja dwuargumentowa,
#     której pierwszym argumentem mogą być elementy klasy Q, zaś drugim
#     elementy klasy Q, ED lub PD)
#
# -   bycie wartością własności (*quale*) – jest to relacja
#     dwuargumentowa, której pierwszym argumentem mogą być tzw. regiony
#     czasowe (*temporal region*) z kategorii TR, zaś drugim jakości
#     czasowe z kategorii Temporal Quality)
#
# Inspiracje lingwistyczne – klasyfikacja PD
#
# 1.  zdarzenia (*events* – EV): klasa $A$ jest klasą zdarzeń, gdy $A$
#     jest podporządkowana PD i mereologiczna suma pewnych dwóch elementów
#     $A$ *nie* należy do $A$.
#
# 2.  statywy (*stative* – STV): klasa $A$ jest klasą statywów, gdy $A$
#     jest podporządkowana PD i mereologiczna suma dowolnych dwóch
#     elementów $A$ należy do $A$.
#
# Inspiracje lingwistyczne – klasyfikacja PD (2)
#
# 1.  zdarzenia: wykład, bieg, *Big Bang*, rozszczepienie jądra atomu.
#
# 2.  statywy: siedzenie, podtrzymywanie, fotosynteza.
#
# Inspiracje lingwistyczne – klasyfikacja PD (3)
#
# 1.  zdarzenia
#
#     -   osiągnięcia (*achievements* – ACH): klasa $A$ jest klasą
#         osiągnięć, gdy $A$ jest podporządkowana EV i żaden element klasy
#         $A$ nie ma części.
#
#     -   realizacje (*accomplishments* – ACC): klasa $A$ jest klasą
#         realizacji, gdy $A$ jest podporządkowana EV i każdy element
#         klasy $A$ ma części.
#
# 2.  statywy:
#
#     -   stany (*states* – ST): klasa $A$ jest klasą stanów, gdy $A$ jest
#         podporządkowana STV i każda część każdego elementu klasy $A$
#         należy do $A$.
#
#     -   procesy (*processes* – PRO): klasa $A$ jest klasą procesów, gdy
#         $A$ jest podporządkowana STV i pewne części każdego elementu
#         klasy $A$ *nie* należą do $A$.
#
# Inspiracje lingwistyczne – klasyfikacja PD (4)
#
# 1.  zdarzenia
#
#     -   osiągnięcia: *Big Bang*, rozszczepienie jądra atomu.
#
#     -   realizacje: wykład, bieg.
#
# 2.  statywy:
#
#     -   stany: siedzenie, podtrzymywanie.
#
#     -   procesy: fotosynteza.
#
# ### BFO
#
# BFO – ontologia realizmu filozoficznego
#
# -   **B**asic **F**ormal **O**ntology
#
# -   ontologia stosowana inspirowana filozofią Arystotelesa
#
# -   *Institut für Formale Ontologie und Medizinische
#     Informationswissenschaft* – <http://ifomis.uni-saarland.de/bfo/>
#
# -   zastosowania: biologia i nauki medyczne
#
# -   metodologia OBO Foundry
#
# -   formalna wielopostaciowość:
#
#     -   wersje 1.0, 1.1, 2.0
#
#     -   język OWL, Isabelle, CLIF
#
# Kategorie BFO
#
# -   kategorie typu SNAP – przedmioty trwającymi w czasie – najbardziej
#     ogólną kategorią jest Continuant.
#
# -   kategorie typu SPAN – procesy lub zdarzenia – najbardziej ogólną
#     kategorią jest Occurent.
#
# Kategorie BFO vs kategorie DOLCE
#
# |          **BFO**           | **DOLCE** |
# |:--------------------------:|:---------:|
# |         Continuant         |    ED     |
# |          Occurent          |    PD     |
# |             \-             |    AB     |
# |          quality           |     Q     |
# | (podkategoria Continuant ) |           |
#
# Filozoficzne założenia BFO
#
# -   realizm – rzeczywistość istnieje niezależnie od poznających ją ludzi
#     i ich schematów pojęciowych
#
# -   perspektywizm – istnieje wiele adekwatnych opisów (tej samej)
#     rzeczywistości (chociaż nie każdy opis jest tak samo wartościowy,
#     jak pozostałe)
#
# -   fallibilizm – teorie naukowe zmieniają się w czasie, odpowiednio do
#     nowych odkryć
#
# -   adekwatyzm – przedmioty w dziedzinie reprezentowanej przez ontologię
#     nie powinny być redukowane do innych przedmiotów
#
# BFO – klasyfikacja Continuant
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/BFO_Continuants.jpg?raw=1) <span id="fig:dolce"
# label="fig:dolce"></span>
#
# BFO – klasyfikacja Occurent
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/BFO_Occurents.jpg?raw=1) <span id="fig:dolce"
# label="fig:dolce"></span>
#
# <http://bioportal.bioontology.org>
#
# Zastosowania BFO
#
# 1.  ACGT Master Ontology
#
# 2.  Adverse Event Ontology
#
# 3.  AFO Foundational Ontology
#
# 4.  Biomedical Ethics Ontology
#
# 5.  Biomedical Grid Terminology
#
# 6.  BioTop
#
# 7.  BIRNLex
#
# 8.  Blood Ontology
#
# 9.  Body Fluids Ontology
#
# 10. Cell Cycle Ontology
#
# 11. Cell Line Ontology (CLO)
#
# 12. Cell Ontology
#
# 13. Chemical Entities of Biological Interest
#
# 14. CHRONIOUS Ontology Suite
#
# 15. Clusters of Orthologous Groups Analysis Ontology
#
# 16. Cognitive Paradigm Ontology
#
# 17. Common Anatomy Reference Ontology
#
# 18. Conceptual Model Ontology
#
# 19. Coriell Cell Line Ontology
#
# 20. CPR ontology
#
# 21. Drug Interaction Ontology
#
# 22. Dynamic Earth Sciences Ontologies
#
# 23. Emotion Ontology
#
# 24. Environment Ontology
#
# 25. EuPathDB
#
# 26. Evolution Ontology
#
# 27. Experimental Factor Ontology
#
# 28. FlyBase
#
# 29. Foundational Model of Anatomy
#
# 30. Gastrointestinal Endoscopy Ontology
#
# 31. **Gene Ontology**
#
# 32. Infectious Disease Ontology
#
# 33. **Information Artifact Ontology**
#
# 34. Interdisciplinary Prostate Ontology
#
# 35. Lipid Ontology
#
# 36. Mental Disease Ontology
#
# 37. Middle Layer Ontology for Clinical Care
#
# 38. Nanoparticle Ontology
#
# 39. Neuroscience Information Framework Standard Ontology
#
# 40. Ontology of Clinical Research
#
# 41. Ontology of Data Mining Investigations
#
# 42. Ontology for Biomedical Investigations
#
# 43. Ontology for General Medical Science
#
# 44. Ontology for Newborn Screening and Translational Research
#
# 45. Ontology of Biomedical Reality for the pathology domain of spine
#     (scoliosis domain)
#
# 46. Parasite Experiment Ontology
#
# 47. Petrochemical Ontology
#
# 48. Phenotypic Quality Ontology
#
# 49. Proteomics data and process provenance ontology
#
# 50. Protein Ontology
#
# 51. RNA Ontology
#
# 52. Saliva Ontology
#
# 53. Senselab Ontology
#
# 54. Sequence Ontology
#
# 55. Sleep Domain Ontology
#
# 56. Subcellular Anatomy Ontology
#
# 57. Translaftional Medicine Ontology
#
# 58. Vaccine Ontology
#
# 59. yOWL
#
# 60. Zebrafish Anatomical Ontology
#
# ### CIDOC CRM
#
# Ontologia CIDOC CRM
#
# -   *International Committee for Documentation of the International
#     Council of Museums*
#
# -   model danych dla systemów reprezentujących informacje o dziedzictwie
#     kulturowym
#
# -   <a href="www.cidoc-crm.org" class="uri">www.cidoc-crm.org</a>
#
# -   ok. 100 kategorii oraz 150 relacji
#
# Ontologia CIDOC CRM – zastosowania
#
# -   wyznaczenie standardu dobrych praktyk w modelowaniu pojęciowym
#     (*conceptual modelling*) systemów informatycznych
#
# -   definicja wspólnego języka, w którym specjaliści z dziedziny
#     dziedzictwa kulturowego (np. muzealnicy, archiwiści, bibliotekarze,
#     itd.) mogliby się porozumiewać z informatykami budującymi systemy
#     komputerowe dla tej dziedziny
#
# -   kodyfikacja języka służącego do automatycznej wymiany danych,
#     migracji danych, integracji danych i negocjacji wymiany danych
#     pomiędzy różnymi systemami komputerowymi
#
# -   ustanowienie platformy, w obrębie której różne systemy informatyczne
#     mogłyby pozyskiwać wzajemnie od siebie informacje za pomocą zapytań
#
# Ontologia CIDOC CRM – specyfika
#
# -   podstawowa (kanoniczna) ontologia jest zapisana w języku etnicznym
#
# -   liczba relacji przekracza liczbę kategorii: kategoria powinna być
#     dziedziną lub przeciwdziedziną jakiejś relacji
#
# -   CIDRO CRM umożliwia reprezentację sprzecznych przekonań
#
# -   awersja do zupełnych i rozłącznych podziałów logicznych
#
# -   CIDOC CRM wspiera tzw. wielokrotną kategoryzację (*multiple
#     inheritance*): jeden przedmiot może być instancją dwóch kategorii, z
#     których żadna nie jest podporządkowana drugiej
#
# Grupy kategorii CIDOC CRM
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/CIDOC.pdf?raw=1)
#
# Wybrane kategorie CIDOC CRM
#
# -   określenia (*appelations*):
#
#     -   $\mathsf{E45 ~Address}$
#
#     -   $\mathsf{E50 ~Data}$
#
#     -   $\mathsf{E35 ~Title}$
#
# -   uczestnicy:
#
#     -   $\mathsf{E21 ~Person}$
#
#     -   $\mathsf{E40~ Legal ~Body}$
#
# -   procesy/zdarzenia:
#
#     -   $\mathsf{E80 ~Part ~Removal}$
#
#     -   $\mathsf{E65 ~Creation}$
#
#     -   $\mathsf{E69 ~Death}$
#
# -   pojęcia:
#
#     -   $\mathsf{E31 ~Design ~or~ Procedure}$
#
#     -   $\mathsf{E30 ~Right}$
#
# Wybrane kategorie CIDOC CRM (2)
#
# -   przedmioty materialne:
#
#     -   $\mathsf{E78 ~Collection}$
#
#     -   $\mathsf{E84~ Information ~Carrier}$
#
# -   miejsca – ta grupa zawiera tylko jedną kategorię:
#     $\mathsf{E53 ~Place}$
#
# -   interwały czasowe – ta grupa zawiera tylko jedną kategorię:
#     $\mathsf{E52 ~Time-Span}$
#
# -   typy – ta grupa obejmuje wszystkie kategorie ontologii
#     $\mathsf{CIDOC ~CRM}$ (jako swe instancje) oraz wszystkie klasy
#     każdego modelu danych, który wykorzystuje tę ontologię
#
# Co to jest ontologia formalna?
#
# 1.  formalna vs nieformalna
#
# 2.  formalna vs lokalna
#
# 3.  formalna vs materialna
#
# 4.  formalna vs “kawiarniana”
#
# CIDOC CRM jako “ontologia formalna”
#
# -   lista kategorii tej ontologii (włączając w to relacje) oraz ich nazw
#     jest ustalona i niezmienna w obrębie każdej wersji tej ontologii
#
# -   opis każdej kategorii ma tę samą strukturę – podobnie rzecz się ma z
#     opisami relacji
#
# -   kategorie tej ontologii są uporządkowane za pomocą relacji
#     subsumpcji, która gwarantuje dziedziczenie własności przez podrzędne
#     klasy
#
# Źródła wiedzy wykorzystane przy konstrukcji $\mathsf{CIDOC  CRM}$
#
# 1.  ontologia $\mathsf{Dublin  Core}$
#
# 2.  model danych zdefiniowany przez *Art Museum Image Consortium*
#
# 3.  standard Encoded Archival Description
#
# 4.  standard SPECTRUM sformułowany przez *Museum Documentation
#     Association*
#
# 5.  słownik Natural History Museum (London) John Clayton Herbarium Data
#     Dictionary
#
# 6.  logiczny schemat bazy danych GENREG będącej własnością
#     *Nationalmuseet*
#
# 7.  model Functional Requirements for Bibliographic Records uzgodniony
#     przez *International Federation of Library Associations and
#     Institutions*
#
# 8.  standard OpenGIS (*Open Geospatial Consortium*)
#
# 9.  standard sformułowany przez *Association of American Museums
#     Nazi-era Provenance*
#
# 10. standard opisu treści multimedialnych MPEG7
#
# 11. schemat metadanych Cultural Materials Initiative wypracowany w
#     ramach *Research Libraries Group*
#
# 12. protokół Z39.50
#
# 13. standard Object ID wypracowany przez *Council for the Prevention of
#     Art Theft*
#
# 14. standard International Core Data Standard for Archaeological and
#     Architectural Heritage ustalony przez CIDOC
#
# 15. indeks Core Data Index to Historic Buildings and Monuments of the
#     Architectural Heritage
#
# 16. standard CIDOC Normes Documentaires (Archeologie)
#
# 17. standardy: English Heritage MIDAS - A Manual and Data Standard for
#     Monument Inventories oraz SMR 97 będące własnością *English
#     Heritage*
#
# 18. schemat POLEMON Data Dictionary zbudowany w ministerstwie kultury
#     Republiki Greckiej
#
# Zastosowania CIDOC CRM
#
# 1.  część schematu danych XML o nazwie LIDO (*Lightweight Information
#     Describing Objects*)
#
# 2.  schemat logiczny bazy danych *Arachne* (*Deutsches Archäologische
#     Institut* oraz
#     *Archäologisches Institut der Universität zu Köln*)
#
# 3.  podstawa integracji baz danych w systemie CLAROS (Classical Art
#     Research Online Services)
#
# 4.  rama pojęciowa dla portalu *The Museum of New Zealand Te Papa
#     Tongarewa*
#
# 5.  szkielet wyszukiwania w systemie STAR (*Semantic Technologies for
#     Archaeological Resources*)
#
# 6.  część trzech definicji DTD (*Document Type Definition*)
#     skonstruowanych przez *Germanische Nationalmuseum Nuremberg*
#
# 7.  schemat danych w aplikacji *Bletchley Park Text*
#
# 8.  część schematu danych w projekcie *LOGOMAR*
#
# 9.  podstawa dokumentacji projektowej dla baz danych w *Valtion
#     Taidemuseo*
#
# 10. schemat danych o artefaktach muzealnych w systemie audialnej
#     reprezentacji danych o nazwie ec(h)o
#
# 11. część schematu danych w produktach grupy AFNOR
#
# ### ISO 15926
#
# ISO 15926 – skomercjalizowana ontologia przemysłowa
#
# -   co to jest ISO?
#
# -   ISO 15926 stanowi część standardu ISO 15926, którego zadaniem jest
#     integracja danych o procesach przemysłowych z uwzględnieniem
#     urządzeń produkujących ropę i gaz, czyli danych o:
#
#     -   zakładach produkcyjnych i procesach w nich zachodzących
#
#     -   własnościach i komponentach tych zakładów,
#
#     -   własnościach i strukturach tych komponentów.
#
# -   początkowo ontologia rozwijana przez konsorcjum *European Process
#     Industries STEP Technical Liaison Executive*, obecnie *POSC Caesar
#     Association*
#
# -   wersje (językowe):
#
#     -   język EXPRESS : komputerowy język (*computer-interpretable*) do
#         reprezentowania oraz wymiany informacji o produktach w czasie
#         tzw. cyklu życia (*life cycle*)
#
#     -   wersja OWL tej ontologii
#
# -   pełna dokumentacja techniczna dla ISO 15926 nie jest dostępna w
#     domenie publicznej
#
# -   <http://15926.org>
#
# Struktura pojęciowa ISO 15926
#
# Filozoficzne inspiracje ISO 15926
#
# 1.  perdurantyzm
#
# 2.  oraz związane z nim ekstensjonalne kryterium identyczności:
#     $$\begin{aligned}
#     &x=y \equiv \nonumber \\
#     &\forall z (z\text{ jest częścią } x \equiv z\text{ jest częścią } y) \nonumber \\\end{aligned}$$
#
# 3.  nie-ufundowana teoria mnogości
#
# Perdurantyzm
#
# Perdurantyzm i mereologia
#
# 1.  Młodość Jana (tzn. Jan jako młodzieniec) jest częścią Jana.
#
# 2.  Głowa Jana, pojęta jako proces rozpościerający się przez całe życie
#     Jana, ale ograniczony tylko do fragmentu ciała Jana, jest częścią
#     Jana.
#
# 3.  Głowa młodego Jana jest częścią:
#
#     -   młodości Jana
#
#     -   głowy Jana
#
#     -   oraz oczywiście samego Jana.
#
# Nieufundowana teoria mnogości
#
# -   aksjomatyczna teoria mnogości – co to jest?
#
# -   teoria zbiorów, która *nie* zakłada tzw. aksjomatu ufundowania:
#     $$\forall X \neq \emptyset ~\exists y \in X ~y \cap X = \emptyset$$
#
# -   brak tego aksjomatu umożliwia tworzenie zbiorów ,,bez fundamentu”,
#     np. $\dots \in x_{n} \in \dots \in x_{2} \in x_{1}$.
#
# -   W ISO 15926 mamy np. aksjomat $\mathsf{Class} \in \mathsf{Class}$,
#     który dotyczy kategorii $\mathsf{Class}$.
#
# Zastosowania ISO 15926
#
# -   system informatyczny *Downstream Data Management* funkcjonujący
#     przez pewien czas w firmie Shell UK
#
# -   projekty FIATECH:
#
#     1.  projekt EDRC
#
#     2.  ADI
#
# -   projetyk konsorcjum *Oljeindustriens Landsforening*:
#
#     1.  Integrated Operations in the High North
#
#     2.  Environment Web
#
#     3.  Daily Drilling Report
#
#     4.  Daily Production Report
#
# ### WordNet
#
# Tezaurus WordNet jako ontologia lingwistyczna
#
# -   WordNet opisuje zależności leksykalne i semantyczne, pomiędzy
#     słowami określonego języka naturalnego (pierwotnie: języka
#     angielskiego): rzeczowniki, czasowniki, przymiotniki i przysłówki są
#     pogrupowane w zbiory synonimów (*synsets*), w taki sposób, że każdy
#     taki zbiór reprezentuje jedno pojęcie.
#
# -   sieć, której węzłami są zbiory synonimów połączone między sobą
#     relacjami leksykalnymi (relacje morfologiczne) i semantycznymi (np.
#     hiponimia, jednoznaczność, przeciwieństwo, przynależność)
#
# -   powstanie: psycholingwistyczne teorie ludzkiej pamięci powstałe w
#     latach osiemdziesiątych XX w.
#
# -   uniwersytet w Princeton: Christiane Fellbaum, George A. Miller, i
#     in.
#
# -   podobne inicjatywy dla innych języków etnicznych:
#
#     -   EuroWordNet: <http://www.illc.uva.nl/EuroWordNet>
#
#     -   Słowosieć: <http://plwordnet.pwr.wroc.pl/wordnet/>
#
# Synsety w WordNecie
#
# -   Każdy termin (słowo, fraza, itp.) występujący w WordNet przynależy
#     do jednego lub więcej zbiorów synonimów.
#
# -   Każdy synset wyraża pojęcie, czy innymi słowy, jest odpowiednikiem
#     znaczenia swoich elementów.
#
# -   Gdy termin należy do zbioru synonimów *A*, posiada inne znaczenie
#     niż wtedy, gdy należy do zbioru synonimów *B*. O przynależności
#     pewnego terminu do danego zbioru synonimów decyduje sposób jego
#     rozumienia i używania przez większość kompetentnych użytkowników
#     danego języka.
#
# Synsety w WordNecie – przykład
#
# -   $\{$*president*, *chairman*, *chairwoman*, *chair*,
#     *chairperson*$\}$
#
# WordNet – statystyka
#
# | **Części mowy** | **Jednostki leksykalne (wyrazy)** | **Synsety** |
# |:---------------:|:---------------------------------:|:-----------:|
# |   Rzeczowniki   |              117798               |    82115    |
# |   Czasowniki    |               11529               |    13767    |
# |  Przymiotniki   |               21479               |    18156    |
# |   Przysłówki    |               4481                |    3621     |
#
# Struktura zbioru rzeczowników synsetów
#
# 1.  WordNet ma strukturę drzewa określoną przez relację subsumpcji:
#
#     1.  Zbiór synonimów *X* jest *hiponimem* zbioru synonimów *Y* jeżeli
#         każdy *X* jest *Y*.
#
#     2.  Zbiór synonimów *X* jest *hiperonimem* zbioru synonimów *Y*
#         jeżeli każdy *Y* jest *X*
#
# 2.  Korzeniem drzewa jest synset entity: *that which is perceived or
#     known or inferred to have its own distinct existence (living or
#     nonliving)*.
#
# Struktura zbioru rzeczowników synsetów – meornimia
#
# -   pomiędzy niektórymi zbiorami synonimów zachodzi relacja meornimii
#
# -   typy meronimii:
#
#     1.  relacja pomiędzy **częścią a całością** (np. zbiór synonimów
#         ,,noga (stołowa)” (*leg*) jest częścią zbioru synonimów ,,stół”
#         (*table*),
#
#     2.  relacja pomiędzy **elementem a grupą**, do której ten element
#         należy (np. zbiór synonimów ,,drzewo” (*tree*) jest elementem
#         zbioru synonimów ,,las” (*forest*),
#
#     3.  relacja pomiędzy **materią a rzeczą**, która jest zbudowana z
#         tej materii (np. zbiór synonimów ,,aluminium” jest w tej relacji
#         do zbioru synonimów ,,folia aluminiowa” (*aluminium foil*).
#
# Zbiór czasowników synsetów – przykłady
#
# -   $\{$*travel*, *go*, *move*, *locomote*$\}$,
#
# -   $\{$*move*, *displace*$\}$,
#
# -   $\{$*go*, *proceed*, *move*$\}$,
#
# -   $\{$*motivate*, *actuate*, *propel*, *move*, *prompt*, *incite*$\}$.
#
# Struktura zbioru czasowników synsetów
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/wordnet-impl-lek.eps?raw=1)
#
# Grupy synsetów czasowników
#
# 1.  czasowniki odnoszące się do funkcji ciała oraz higieny (np. pocić
#     się, chrapać, ubierać się),
#
# 2.  czasowniki wyrażające zmianę (np. zmieniać, modyfikować, cofać,
#     dostosowywać się),
#
# 3.  czasowniki odnoszące się do komunikacji wymiany informacji (np.
#     dziękować, zamawiać, seplenić),
#
# 4.  czasowniki związane z rywalizacją (np. atakować, zbroić),
#
# 5.  czasowniki związane z konsumpcją (np. jeść, pić),
#
# 6.  czasowniki kontaktu fizycznego (np. wiązać, pocierać, dotykać),
#
# 7.  czasowniki wyrażające procesy i stany kognitywne (np. uczyć się,
#     sądzić, dedukować),
#
# 8.  czasowniki wyrażające procesy wytwarzania (np. tworzyć, wynajdować,
#     piec),
#
# 9.  czasowniki wyrażające ruch (np. ruszać się, potrząsać),
#
# 10. czasowniki odnoszące się do emocji i stanów psychicznych (np. bać
#     się, tęsknić, kochać),
#
# 11. czasowniki wyrażające niezmienne stany (np. być, mieć),
#
# 12. czasowniki wyrażające procesy percepcji (np. oglądać, rozglądać się,
#     wąchać),
#
# 13. czasowniki odnoszące się do posiadania (np. mieć, posiadać,
#     odbierać),
#
# 14. czasowniki odnoszące się do działań społecznych (np. oskarżać,
#     składać pozew),
#
# 15. czasowniki opisujące pogodę (np. śnieżyć, mżyć).
#
# Struktura zbioru czasowników synsetów
#
# ![image](https://github.com/trypuz/ai_dla_kazdego/blob/main/sieci%20semantyczne/img/wordnet-przymiotniki.eps?raw=1)
#
# Typy przymiotników synsetów
#
# -   Przymiotniki opisowe (*ascriptive adjectives*), które denotują
#     własności przedmiotów, np. *heavy* i *high*. Są one pogrupowane
#     przez relacje **przeciwieństwa** – oznaczanej w dokumentacji
#     WordNetu przez ,,!$\to$” oraz **podobieństwa** – oznaczanej przez
#     ,,&$\to$”. Na przykład: *moist* &$\to$ *wet* !$\to$ *dry*
#
# -   Przymiotniki nie-opisowe (*nonascriptive adjectives*, *pertainyms*),
#     które nie denotują własności, lecz denotują treści przedstawień
#     mentalnych. Np. w ontologii WordNetu przymiotnik *green* nie
#     denotuje cechy przedmiotów zielonych, lecz to, co myślą, ci którzy
#     posługują się tym przymiotnikiem.
#
# Zastosowania WordNetu
#
# -   ujednoznacznianie znaczeń wyrażeń
#
# -   klasyfikacja dokumentów
#
# -   wyszukiwania informacji w tekście
#
# -   wyszukiwanie informacji w Internecie
#
# ### DBpedia
#
# DBpedia – ontologia Wikipedii
#
# -   <http://wiki.dbpedia.org/>
#
# -   dwa komponenty:
#
#     1.  <http://dbpedia.org/ontology/>
#
#         -   ok. 700 kategorii
#
#         -   ok. 3000 relacji
#
#     2.  <http://dbpedia.org/resource/>
#
#         -   ok. 4M indywiduów (zasobów), m. in., ok. 1.5M osób, 700k
#             miejsc, 500 dzieł (*works*)
#
# Ontologia DBpedii
#
# > Ontologia DBpedii jest płytką, inter-dyscyplinarną ontologią, która
# > została ręcznie stworzona na podstawie najbardziej typowych infoboksów
# > z Wikipedii. Ontologia obecnie objemuje 685 kategeorii, które tworzą
# > hierarchię subsumpcyjną i są opisane za pomocą 2 795 relacji. \[…\] Od
# > czasu wersji 3.7 ontologia jest acyklicznym skierowanym grafem, nie
# > drzewem. Kategorie mogą mieć liczne nadkategorie, co jest istotne dla
# > odwzorowań do schema.org.
#
# <http://wiki.dbpedia.org/services-resources/ontology> (dostęp 15 I 2018
# r.)
#
# Ontologia DBpedii – z bliska

# %% [markdown]
# ## Bibliografia
#
# -   J. Sowa, *Knowledge Representation: Logical, Philosophical, and
#     Computational Foundations*, Brooks Cole Publishing Co., Pacific
#     Grove, CA, 2000
#
# -   R. Brachman, H. Levesque, *Knowledge Representation and Reasoning*,
#     Morgan Kaufmann 2004
#
# -   F. van Harmelen i in., *Handbook of Knowledge Representation*,
#     Elsevier, Amsterdam 2008
#
# -   Krzysztof Goczyła, *Ontologie w systemach informatycznych*, EXIT
#     2011
#
# -   R. Fagin i in., *Reasoning about Knowledge*, MIT Press 1995.
