# %% [markdown]
# # Wprowadznie do sieci semantycznej
#
# ## Spis treści
# - Problem szukania informacji
# - Koncepcja informacji
# - Podstawy Linke Open Data
# - Serializacje
# - RDF
# - RDFS
# - OWL

# %% [markdown]
# ## Problem szukania informacji
#
# ### Problem nadmiaru
#
# 1.  w roku 2007 wyprodukowaliśmy 295 exabajtów ($\approx 10^{18}$
#     bajtów) skompresowanych danych
#
#     -   ok. 60 płyt CD-ROM / osobę
#
#     -   ok. 10 płyt DVD / osobę
#
#     -   ok. 1 twardy dysk (1TB) / 100 osób
#
# 2.  wzrost o:
#
#     1.  6100 $\%$ w stosunku do 1986 r.
#
#     2.  500 $\%$ w stosunku do 2000 r.
#
# 3.  podział na kategorie nośników:
#
#     -   twarde dyski $52\%$
#
#     -   dyski optyczne $28\%$
#
#     -   taśma magnetyczna (zapis cyfrowy) $11\%$
#
#     -   …
#
#     -   papier $0.007\%$
#
# 4.  przeciętny człowiek jest w stanie zapamiętać w sposób trwały w ciągu
#     całego swego życia ok. $200$ megabajtów danych (1 megabajt
#     $\approx 10^{6}$ bajtów).
#
#
# ### Jak ludzie szukają informacji?
#
# ![image](img/wikiandgoogle.jpg)
#
# Jak ludzie szukają informacji? (2)
#
# 1.  Co to jest heksakosjoiheksekontaheksafobia?
#
# 2.  Jacy filozofowie urodzili się w Lublinie?
#
# 3.  W którym filmie brało udział najwięcej aktorów?
#
# 4.  Jakie filmy zostały nominowane zarazem do Oscara i BAFTA?
#
# ### Jak szukać informacji filozoficznej w Internecie?
#
# 1.  <a href="www.wikipedia.com" class="uri">www.wikipedia.com</a>
#
# 2.  *Stanford Encyclopedia of Philosophy*
#     <http://www.science.uva.nl/~seop>
#
# 3.  *Powszechna Encyklopedia Filozoficzna* <http://www.ptta.pl/pef/>
#
# 4.  wortal <a href="www.filozofia.pl" class="uri">www.filozofia.pl</a>
#
# 5.  <http://academicon.pl/>
#
# ### Jak szukać informacji bibliograficznej?
#
# 1.  bazy danych dostępne w domenie publicznej
#
#     -   dla nauk wszelkich: <http://scholar.google.com>
#
#     -   dla filozofii: *PhilPapers* (<http://philpapers.org/>)
#
#     -   dla informatyki:
#
#         -   *The DBLP Computer Science Bibliography*
#             (<http://www.dblp.org/search>)
#
#         -   *Digitial Library of ACM* (<http://dl.acm.org/>)
#
#     -   dla biologii i medycyny: *PubMed*
#         (<http://www.ncbi.nlm.nih.gov/pubmed/>)
#
# 2.  komercyjne bazy danych (zob. zakładka Zasoby wiedzy na e-KUL)
#
#     -   uniwersalne
#
#         -   JSTOR (głównie humanistyka)
#
#         -   EBSCO (głównie nauki społeczne)
#
#         -   ScienceDirect (głównie informatyka i inżynieria)
#
#         -   Scopus (nauki wszelkie) - cytowania
#
#         -   Web of Knowledge - <http://apps.webofknowledge.com> (nauki
#             wszelkie) - cytowania
#
#         -   …
#
#     -   lokalne
#
#         -   Springer - <a href="www.springerlink.com/journals"
#             class="uri">www.springerlink.com/journals</a>
#
# ### Jak szukać informacji bibliograficznej - praktyka
#
# 1.  Znajdź publikacje z dziedziny informatyki poświęcone ontologii!
#
# 2.  Znajdź publikacje z 2011 r. poświęcone grafenowi!
#
# 3.  Znajdź publikacje, które cytują *In Defense of the Selfish Gene*
#     Richarda Dawkinsa!
#
# 4.  Znajdź filozoficzne publikacje, które dotyczą ewolucji, lecz których
#     nie napisał Richard Dawkins!
#
# 5.  Znajdź recenzje publikacji dotyczących Boga z dziedziny filozofii!
#
# 6.  Znajdź najczęściej cytowany artykuł filozoficzny!
#
# 7.  Jakie artykuły napisał Tadeusz Szubka?
#
# 8.  W którym roku Tadeusz Szubka opublikował najwięcej artykułów?
#
# 9.  Ile opublikowano polskich artykułów filozoficznych!
#
# 10. W jakiej dziedzinie opublikowano najwięcej artykułów?
#
# ### Jak maszyny szukają wiedzy?
#
# Maszyna Turinga
#
# ![image](img/TuringMachine.png)
#
# **Definicja 1**. **Maszyna Turinga* jest siódemką
# $<S, s_{0}, Q, L, \emptyset, I, \delta>$:*
#
# 1.  *skończony zbiór $S$ możliwych stanów maszyny z wyróżnionym stanem
#     początkowym $s_{0}$ i stanami końcowymi (akceptującymi)
#     $Q \subseteq S$;*
#
# 2.  *skończony zbiór symboli $L$ z symbolem pustym $\emptyset \in L$
#     oraz podzbiorem symboli początkowych $I \subset L$;*
#
# 3.  *funkcja przejścia
#     $\delta: S \times L \to S \times L \times \{\text{w lewo}, \text{stój}, \text{w prawo}\}$.*
#
# <https://turingmachinesimulator.com/>
#
# Wiedza w maszynie Turinga …
#
# ![image](img/sign1.jpg)
#
# …i wiedza w człowieku
#
# ![image](img/sign2.jpg)
#
# Reprezentacja wiedzy
#
# **Definicja 2**.
#
# > *Reprezentacja wiedzy jest multidyscyplinarną dziedziną, która stosuje
# > teorie i metody z trzech obszarów:*
# >
# > 1.  **logiki* \[która\] określa formalną strukturę \[reprezentacji
# >     wiedzy\] i reguły wnioskowania*
# >
# > 2.  **ontologii* \[która\] definiuje rodzaje rzeczy, które istnieją w
# >     dziedzinie zastosowania \[reprezentacji wiedzy\]*
# >
# > 3.  **informatyki* (*computation*) \[która\] wspiera aplikacje
# >     odróżniające reprezentację wiedzy od czystej filozofii*
# >
# > **
#
# Problem semantyczny reprezentacji wiedzy
#
# 1.  problemy ze **znaczeniem** (**sensem**)
#
#     1.  Warszawa jest stolicą Polski.
#
#     2.  Warszawa jest stolicą Polski.
#
#     3.  Stolicą Polski jest Warszawa.
#
#     4.  Warszawa jest siedzibą rządu Polski.
#
#     5.  sdfe@@!! \>\<,. ssssssą \>?\>?\>?.
#
# 2.  problemy z **wnioskowaniem**
#
#     -   Warszawa jest stolicą Polski.
#
#     -   Warszawa jest miastem.

# %% [markdown]
# ## Koncepcje informacji
#
# ### Informacja jako miara falsyfikowalności (K. Popper)
#
# 1.  falsyfikacjonizm
#
# 2.  Ilość informacji empirycznej (teorii naukowej) zwiększa się wraz ze
#     stopniem jej falsyfikowalności.
#
# 3.  dwa rodzaje prawdopodobieństwa:
#
#     1.  logiczne
#
#     2.  numeryczne
#
# 4.  falsyfikowalność $\approx$ logiczne prawdopodobieństwo
#
# ### Informacja jako miara niepewności
#
# -   Ile informacji zyskujemy grając w “pomidora”?
#
# -   Ile informacji zyskujemy, dowiadując się, że w rzucie monetą
#     wyrzucono orła?
#
# -   Ile informacji zyskujemy dowiadując się, że na kostce wyrzucono 6?
#
# -   Miara informacji jest wielkością niepewności/deficytu poznawczego
#     usuniętego w wyniku otrzymania komunikatu (C. Shannon).
#
#
# **Definicja 3**. *Niech $x$ będzie zdarzeniem (komunikacyjnym), którego
# prawdopodobieństwo wynosi $p$. Wówczas miara informacji przenoszona
# przez to zdarzenie wynosi $$h = -\log_2 p.$$*
#
#
# |                     **Zdarzenie**                     | **Prawdopodobieństwo** | **Informacja** |
# |:-----------------------------------------------------:|:----------------------:|:--------------:|
# |                  wynik rzutu monetą                   |     $\frac{1}{2}$      |       1        |
# |        zwycięstwo A. Dudy w II. turze wyborów         |     $\frac{1}{2}$      |      $1$       |
# |                  wynik rzutu kostką                   |     $\frac{1}{6}$      | $\approx 2.59$ |
# | zwycięstwo G. Johnsona w wyborach prezydenckich w USA |         $0.06$         | $\approx 4.06$ |
# |             wynik wyborów parlamentarnych             |          ???           |      ???       |
#
#
# **Definicja 4**. *Niech $\{x_i\}$ ($0 \leq i \leq n$), będzie skończonym
# zbiorem zdarzeń komunikacyjnych, takich że prawdopodobieństwo zdarzenia
# $x_i$ wynosi $p_i$. Wówczas miara informacji przenoszona przez ten zbiór
# zdarzeń wynosi $$H = -\sum_{i=1}^n p_i \log_2 p_i.$$*
#
# Założenia:
#
# 1.  Zbiór $\{x_i\}$ jest dyskretny.
#
# 2.  Zdarzenia z $\{x_i\}$ są niezależne.
#
# 3.  Zbiór $\{x_i\}$ jest ergodyczny.
#
# ### Jakościowa teoria informacji M. Mazura
#
# **Definicja 5**. *Informacja jest to transformacja jednego komunikatu
# asocjacji informacyjnej w drugi komunikat tej asocjacji.*
#
# **Definicja 6**. *Tor sterowniczy jest to system, za pomocą którego
# jeden system oddziałuje na inny system.*
#
# **Definicja 7**. *Komunikat jest to stan fizyczny (elementu) toru
# sterowniczego.*
#
# **Definicja 8**. *Zbiór poprzeczny komunikatów jest to zbiór komunikatów
# w pewnym miejscu toru sterowniczego.*
#
# **Definicja 9**. *Asocjacja komunikatów jest to nieuporządkowana para
# komunikatów.*
#
# **Definicja 10**. *Transformacja (asocjacji komunikatów) jest to proces
# zmiany jednego komunikatu (asocjacji) w drugi komunikat (tej
# asocjacji).*
#
# **Definicja 11**. *Asocjacja informacyjna jest to asocjacja komunikatów
# z poprzecznego zbioru komunikatów.*
#
# Jakościowa teoria informacji M. Mazura (4)
#
# **Definicja 12**. *Informacja jest to transformacja jednego komunikatu
# asocjacji informacyjnej w drugi komunikat tej asocjacji.*
#
# ### Informacja semantyczna
#
# *General Definition of Information* (L.
# Floridi)
#
# **Definicja 13**. *$x$ jest informacją, gdy:*
#
# 1.  *$x$ jest złożone z danych*
#
# 2.  *dane te są poprawnie zbudowane*
#
# 3.  *dane te są sensowne*
#
#
# ![image](img/Sign.jpg)
#
# Informacja semantyczna (3)
#
# -   *Dana* jest to różnica pomiędzy dwoma bytami w pewnym kontekście.
#
#     > In fact, what we mean by information \[…\] is a difference which
#     > makes a difference. ()
#
# -   rodzaje danych
#
#     -   rzeczy
#
#     -   percepcje
#
#     -   symbole
#
#
# -   tezy o neutralności
#
#     1.  Dana jest relacją (pomiędzy czymkolwiek a czymkolwiek).
#
#     2.  Istnieją różne typy danych (i różne typy informacji).
#
#     3.  Nie ma informacji bez danych.
#
#     4.  Informacja semantyczna ma znaczenie niezależnie od istnienia jej
#         odbiorców.
#
#
#
# -   rodzaje danych:
#
#     1.  pierwotne, np. rekordy w bazie danych;
#
#     2.  dane wtórne = brak danych pierwotnych, np. odpowiedź *Found 0
#         records* na zapytanie do bazy danych;
#
#     3.  metadane = dane o danych, np. specyfikacja formatu pliku ’.pdf’;
#
#     4.  dane operacyjne = dane o działaniu systemu przechowującego dane
#         pierwotne;
#
#     5.  dane pochodne = dane pochodzące z danych pierwotnych, np.
#         identyfikacja osoby po IP komputera, który najczęściej używa.
#
#
#
# <img src="img/SemInfTypes.jpg" alt="image" /> <span
# label=""></span>
#
# ### Informacja jako miara złożoności (opisu)
#
# 1.  Informacja zawarta w (binarnym) łańcuchu $s$ jest długością
#     najkrótszego programu, który wytwarza $s$ w uniwersalnej maszynie
#     Turinga. (R. Solomonoff, A. Kołmogorow, G. Chaitin)
#
# 2.  Bardziej ogólnie, informacja zawarta w łańcuchu $s$ jest długością
#     najkrótszego opisu tego łańcucha (w pewnym ustalonym języku).
#
# ## Typy zasobów danych ze względu na typ modelu danych
#
# Podział zasobów danych ze względu na typ modelu danych
#
# 1.  zasoby danych bez struktury (*unstructured*)
#
# 2.  zasoby danych z niejawną strukturą (*semistructured*)
#
# 3.  strukturalne zasoby danych (*structured*)
#
#     1.  zasoby hierarchiczne
#
#     2.  zasoby relacyjne
#
#     3.  zasoby obiektowe
#
#     4.  zasoby sieciowe/grafowe (*graph-like*)
#
# ### Hierarchiczne zasoby danych
#
# <img src="img/folders.jpg" alt="image" />
#
#
# <img src="img/XmlExample.jpg" alt="image" />
#
# ### Relacyjne zasoby danych
#
# ![image](img/DB1.png)
#
#
#
# ![image](img/DB2.png)
#
#
#
# -   logiczne podstawy relacyjnych baz danych:
#
#     -   tabelka jako relacja
#
#     -   wiersz tabelki/rekord jako $n$-tka uporządkowana
#
#     -   baza danych jako struktura relacyjna
#
#     -   relacje w logice
#
#         1.  kolejność argumentów jest istotna
#
#         2.  argumenty relacji nie muszą mieć nazw/identyfikatorów
#
#     -   relacje w relacyjnym modelu danych
#
#         1.  kolejność argumentów nie jest/nie musi być istotna
#
#         2.  argumenty relacji muszą mieć nazwy/identyfikatory
#
# ## Podstawowe pojęcia z teorii wyszukiwania informacji
#
# ### Podstawowe miary jakości wyszukiwania
#
# 1.  poprawność (*precision*)
#
# 2.  pełność (*recall*)
#
# 3.  F-miara (*F-measure*)
#
# ...
#
# 1.  $tp$ (*true positive*) – znalazł i powinien znaleźć
#
# 2.  $tn$ (*true negative*) – nie znalazł i nie powinien znaleźć
#
# 3.  $fp$ (*false positive*) – znalazł i nie powinien znaleźć
#
# 4.  $fn$ (*false negative*) – nie znalazł i powinien znaleźć
#
#
#
# Zadajemy serwisowi
# <https://www.wolframalpha.com> pytanie: znajdź rodziców Osamy bin
# Ladena.
# W odpowiedzi dostajemy zbiór
# $A = \{\text{Mohammed bin Awad bin Laden}, \text{Hamida al-Attas}, \text{Muhammad al-Attas}\}$.
#
# 1.  $tp = \{\text{Mohammed bin Awad bin Laden}, \text{Hamida al-Attas}\}$
#
# 2.  $tn = \{\text{Paweł Garbacz}, \dots \}$
#
# 3.  $fp= \{\text{Muhammad al-Attas}\}$
#
# 4.  $fn = \emptyset$
#
#
#
# Zasób danych zawiera $n$
# przedmiotów $D = \{d_1, d_2, \dots, d_n \}$.
# Zadajemy **pytanie**:
#
# Znajdź wszystkie przedmioty $d$, które spełniają warunek: $\phi(d)$!
#
# Na przykład:
#
# Znajdź wszystkie przedmioty $d$, które spełniają warunek $\phi$:
# $d$ jest rodzicem Osamy bin Ladena.
#
# W **odpowiedzi** dostajemy zbiór
# $A = \{d_{i_1}, d_{i_2}, \dots, d_{i_j} , \dots, d_{i_k} \} \subseteq D$
# ($i_j$: $1 \leq i_j \leq n$).
#
# 1.  $tp = A \cap \{d_i : \phi(d_i) \}$
#
# 2.  $tn = \overline{A} \cap \{d_i : \neg \phi(d_i) \}$
#
# 3.  $fp= A \cap \{d_i : \neg \phi(d_i) \}$
#
# 4.  $fn = \overline{A} \cap \{d_i : \phi(d_i) \}$
#
# Poprawność $$precision = \frac{|tp|}{|tp \bigcup fp|}
# \label{eq:precision}$$
#
# Pełność $$recall = \frac{|tp|}{|tp \bigcup fn|}
# \label{eq:recall}$$
#
# F-miara
# $$f_{measure} = 2 \times \frac{precision \times recall}{precision + recall}$$
#
#
# Zadajemy serwisowi
# <https://www.wolframalpha.com> pytanie: znajdź rodziców Osamy bin
# Ladena.
# W odpowiedzi dostajemy zbiór
# $A = \{\text{Mohammed bin Awad bin Laden}, \text{Hamida al-Attas}, \text{Muhammad al-Attas}\}$.
# $$\begin{aligned}
# precision = \frac{2}{3} \pause  \\
# recall = \frac{2}{2} = 1 \pause  \\
# f-measure = 2 \times \frac{\frac{2}{3} \times 1}{\frac{2}{3} + 1} = \frac{4}{5}\end{aligned}$$

# %% [markdown]
# # Podstawy zasobów typu Linked Data
#
# Chmura LOD
#
# Ranking zasobów danych – perspektywa LOD
#
# ![image](img/LODMug.jpg)
#
# Ranking zasobów danych – perspektywa LOD (2)
#
# 1.  Zasób danych jest dostępny poprzez Internet.
#
# 2.  Zasób danych jest ustrukturyzowany w formacie “zrozumiałym” dla
#     komputera.
#
# 3.  Zasób danych jest ustrukturyzowany w publicznie dostępnym formacie
#     “zrozumiałym” dla komputera.
#
# 4.  Zasób danych jest opublikowany zgodnie ze standardami *World Wide
#     Web Consortium* (<https://www.w3.org/>)
#
# 5.  Zasób danych spełnia wszystkie poprzednie warunki i zawiera
#     odniesienia (*links*) do innych zasobów danych.
#
# Reguły LOD Przy tworzeniu zasobu danych:
#
# 1.  do nazywania (rzeczy) używaj nazw typu URI!
#
# 2.  używaj URI ze schematu http!
#
# 3.  używaj URI w standardzie W3C!
#
# 4.  używaj odniesień do innych URI!
#
# URI
#
# -   URI = *Uniform Resource Identifier*
#
# -   standard <https://tools.ietf.org/html/rfc3986>
#
# -   rodzaje URI:
#
#     1.  URN (*Uniform Resource Name*)
#
#     2.  URL *Uniform Resource Locator*
#
# Przykłady URI
#
# -   <http://www.kul.pl/>
#
# -   mailto:John.Doe@example.com
#
# -   tel: $+48 814454238$
#
# -   doi:10.1007/s11229-011-9885-9
#
# Przykłady URI (2)
#
# |                               **URI**                                | **URL** | **URN** |
# |:--------------------------------------------------------------------:|:-------:|:-------:|
# |                         <http://www.kul.pl/>                         |   tak   |   nie   |
# | <http://dbpedia.org/page/John_Paul_II_Catholic_University_of_Lublin> |   tak   |   tak   |
# |                          NIP:712-016-10-05                           |   nie   |   tak   |
# |             Katolicki Uniwersytet Lubelski Jana Pawła II             |   nie   |   nie   |
#
# URL vs URN
#
# Podstawowa składnia URI
#
#     URI = scheme ":" hier-part [ "?" query ] [ "#" fragment ]
#
# Podstawowa składnia URI – przykład
# $$\underbrace{\text{http}}_{schema} \text{:} \underbrace{\text{//www.kul.pl/}}_{hier-part}$$
#
# URI vs IRI ASCII vs. ISO/IEC 10646
#
# |   **identyfikator**    | **URI** | **IRI** |
# |:----------------------:|:-------:|:-------:|
# | http://pawełgarbacz.pl |   nie   |   tak   |
# | http://pawelgarbacz.pl |   tak   |   tak   |
#
# URI vs IRI
#
# Podstawowa struktura LOD
#
# ![image](img/triple.jpg)
#
# Podstawowa struktura LOD – przykład
#
# ![image](img/tripleex.jpg)

# %% [markdown]
# ## RDF czyli system opisu zasobów
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/f/f3/Rdf_logo.svg"
#      alt="RDF logo" align="right" width="100" height="100"/>
#
# RDF to skrót angielskiej nazyw *Resource Description Framework*, czyli system opisu zasobów. RDF jest jednym ze standardów [W3C](https://www.w3.org/RDF/) przeznaczonym do zapisu informacji/wiedzy w sposób przetwarzalny komputerowo.
# Pierwsza wersja standardu RDF została wydana przez W3C w 1997 roku (nota bene, razem z pierwszą specyfikacją języka XML). Standard RDF jest jednym z filarów semantycznego internetu (ang. *Semantic Web*).

# %% [markdown]
# ### Trójki
#
# Podstawowym założeniem, a nawet ograniczeniem, standardu RDF jest sposób zapisu informacji. Mianowicie, każde stwierdzenie musi składać się z trzech elementów: podmiotu, orzeczenia i dopełnienia, np.
# - `Ala` (podmiot) `ma` (orzeczenie) `kota` (dopełnienie).
# - `Jan` (podmiot) `mieszka w` (orzeczenie) `Chełmie` (dopełnienie).
#
# Stwierdzenia RDF będą więc zawsze takie postaci:
#
# - `(podmiot, orzeczenie, dopełnienie)`
#
# Orzeczenie nazywane jest często predykatem i jest relacją łączącą podmiot z dopełnieniem. Dopełnienie może być obiektem lub wartością (literałem):
#
# <img src='https://github.com/trypuz/ai_dla_kazdego/blob/main/pliki_yEd/trojki.png?raw=1'>
#
# W RDF mówi się, że wszystko jest zasobem (ang. *resource*). Ja jestem zasobem, Twoje życie jest zasobem, dokument tekstowy na dysku jest zasoben, etc. Wszystko. Zasoby do których odnosimy się w trójkach RDF nie muszą być faktycznie ,,czymś'' zapisanym na dysku komputera. URI zasobów nie muszą wskazywać plików – mogą reprezentować dowolne obiekty/byty obecne w świecie rzeczywistym. Również to co utworzymy za pomocą języka RDF jest zasobem!
#
# Graf RDF = zbiór trójek RDF
#
# ```
#  (podmiot_0, predykat_0, obiekt_0),
#  (podmiot_1, predykat_1, obiect_1),
#  ...
#  (podmiot_N, predykat_N, obiekt_N)
# ```

# %% [markdown]
# ### Identyfikatory URI
#
# Aby móc skonstruować trójkę, która mówi coś o jakimś zasobie, zasób ten musi mieć swój indetyfikator. Dokładnie rzecz ujmując, identyfikator ten mus być adresem URI. URI to skrót od *Uniform Resource Identifier* (ujednolicony identyfikator zasobu). Najczęściej URI jest URL (skrót od *Uniform Resource Locator*), czyli wygląda jak adres strony www: `https://domenta/ścieżka_do_zasobu`. Możesz też usłyszeć, że identyfikatorami zasobów RDF są typu IRI (skrót od ang. *Internationalized Resource Identifier*). IRI to takie URI, w którym mogą pojawić się znaki spoza alfabetu angielskiego, np. znaki specyficzne dla języka polskiego.
#
# W RDF, jeśli chcemy powiedzieć, że Jan lubi Anię lub chcemy wyrazić fakt, że Jan ma 186cm wzrostu, to musimy najpierw stworzyć identyfiaktory dla Jana, Ani oraz predykatów lubi i ma wzrost.
#
# <img src='https://github.com/trypuz/ai_dla_kazdego/blob/main/pliki_yEd/trojki_przyklad.png?raw=1'>
#
# Pierwszym krokiem tworzenia grafu RDF dla pewnej dziedziny jest przydzielenie pewnego wydzielonego adresu (np. `http://ai.kul.pl/vocab`) jako bazy słownika nazw zasobów.
# Odnośnik URI zasobu składa się z bazy, po którym następuje znak „/” lub „#” - my będziemy preferować pierwszą opcję - a następnie identyfikator danego fragmentu (np. `http://ai.kul.pl/Jan`). Pamiętaj, że w identyfikatorach URI rozróżniane są małe i duże litery!
#
# Identyfikatory URI dla zasobów z powyższego przykładu mogłyby wyglądać ta:
#
# - `http://ai.kul.pl/vocab/Jan`
# - `http://ai.kul.pl/vocab/Ania`
# - `http://ai.kul.pl/vocab/lubi`
# - `http://ai.kul.pl/vocab/ma_wzrost`
#
#
# <img src='https://github.com/trypuz/ai_dla_kazdego/blob/main/pliki_yEd/trojki_przyklad_uri.png?raw=1'>
#
# URI zasobów RDF nie są też przewidziane do bezpośredniego wykorzystania jak hierłącza (tj. linki na stronach www).
#
# Znaczenie danego URI zależy od właściciela domeny (jego pożądane interpretacja jest umowna).

# %% [markdown]
# ### Węzły anonimowe
#
# podmiot i obiekt

# %% [markdown]
# ## Serializacje

# %% [markdown]
# Graf RDF jest strukturą abstrakcyjną, składa się z wierzchołków i krawędzi. Połączenie dwóch wierzchołków grafu tworzy trójkę. I jak powiedzieliśmy wcześniej, graf RDF można traktować jako zbriór trójek. Jeśli chcemy zapisać taki graf w pliku na dysku, to musimy dokładnie zdefiniować sposób reprezentacji trójek. Ściśle zdefiniowany sposób zapisu grafu RDF do pliku nazywamy jego serializacją.
#
# <img src='https://github.com/trypuz/ai_dla_kazdego/blob/main/pliki_yEd/serializacja.png?raw=1'>

# %% [markdown]
#  RDF/XML, N3, NTriples, N-Quads, Turtle, TriX, RDFa, Microdata i JSON-LD

# %% [markdown]
# ### Turtle
# https://www.w3.org/TR/2014/REC-turtle-20140225/
#
#
# `<http://ai.kul.pl/vocab/Jan> <http://ai.kul.pl/vocab/lubi> <http://ai.kul.pl/vocab/Ania> .`
#
# `@prefix`
#
# `http://www.w3.org/1999/02/22-rdf-syntax-ns#`
#
# `@base`
#
# `rdf:type` `a`
#
# `rdf:Property`a

# %% [markdown]
# O tym, co najważniejsze
#
# > \- Dla kupców - rzekł poważnie rządca Fierabras - nie ma złych dróg,
# > przynajmniej dla takich, co serio swój traktują proceder. U nich,
# > \[…\], taka jest zasada: skoro cel przyświeca, sposób musi się
# > znaleźć.
# >
# > \- Zaiste - powiedział wolno \[…\] - zasada to celna i godna
# > naśladowania. W każdej sytuacji.
# >
# > \- Bez ochyby. Ale tak po prawdzie, to niektórzy z handlarzy tkwią to
# > od jesieni, wyjechać nie mogąc. Ale duchem nie padają, mówią, pry, co
# > tam, za to wiesną pierwsi będziemy, nim konkurencja się zjawi. U nich
# > to się nazywa: dumać pozytywnie.
# >
# > \- I tej zasadzie - kiwnął głową \[…\] - trudno coś zarzucić. Jedna
# > rzecz mnie jeszcze ciekawi, panie rządco. Dlaczego ci kupcy siedzą tu,
# > na odludziu, a nie w Beauclair? Księżna nie kwapi się, by udzielać im
# > gościny? Może gardzi kupcami?
# >
# > \- Beauclair, powiadają, to nic jeno uczty, bale, hulanki, pijatyki i
# > miłostki. Człek, powiadają, jeno gnuśnieje, durnieje i czas traci,
# > miast myśleć o handlu. A myśleć trza o tym, co naprawdę ważne. O celu,
# > po przyświeca. Nieustannie. Nie rozpraszając myśli na jakieś tam
# > faramuszki. Wtedy, i tylko wtedy, cel zamierzony się osiąga.

# %% [markdown]
# ## RDF
#
# Sieć Semantyczna
#
# ![Rysunek z ](img/SemanticWeb.jpg)
#
# Graf RDF – przykład
#
# ![https://www.w3.org/TR/rdf11-primer/](img/example-graph.jpg)
#
# Co to jest RDF?
#
# > Resource Description Framework (RDF) jest środowiskiem (*framework*)
# > dla wyrażania informacji o zasobach (*resource*). Zasobem może być
# > wszystko, np. dokumenty, ludzie, przedmioty fizyczne i pojęcia
# > abstrakcyjne.
# > RDF jest przeznaczony dla aplikacji \[programów komputerowych\], które
# > przetwarzają informacje w Internecie \[…\]. RDF jest wspólnym
# > środowiskiem, w który można wyrażać informacje w taki sposób, że jej
# > wymiana \[pomiędzy różnymi systemami komputerowymi\] nie prowadzi do
# > utraty jej znaczenia (sensu).
#
# -   <https://www.w3.org/TR/rdf-primer/>
#
# -   <https://www.w3.org/TR/rdf-syntax-grammar/>
#
# -   <https://www.w3.org/TR/rdf-mt/>
#
# Podstawowe pojęcia RDF
#
# 1.  trójka RDF
#
# 2.  zasób
#
# 3.  własność (relacja)
#
# 4.  nazwa kwalifikowana
#
# 5.  literał
#
# 6.  pusty węzeł (*blank node*)
#
# 7.  słowniki RDF
#
# Trójki RDF – przykład
#
# ![image](img/rdftripleex.jpg)
#
# Trójki RDF – przykład (2)
#
# ![image](img/rdftripleex2.jpg)
#
# Trójki RDF – przykład (3)
#
# ![image](img/RdfGraph.jpg)
#
# Nazwy kwalifikowane – przykład
#
# -   nazwa niekwalifikowana:
#
#     -   <http://dbpedia.org/resource/Garbacz>
#
#     -   <http://dbpedia.org/resource/Lublin>
#
#     -   <http://dbpedia.org/resource/Prince>
#
# -   nazwa kwalifikowana:
#
#     -   dbr:Garbacz
#
#     -   dbr:Lublin
#
#     -   dbr:Prince
#
#     -   @prefix dbr: http://dbpedia.org/resource/
#
# Nazwy kwalifikowane
#
#     QName ::= PrefixedName| UnprefixedName
#     PrefixedName    ::= Prefix ':' LocalPart
#     UnprefixedName ::= LocalPart
#     Prefix ::=  NCName
#     LocalPart    ::= NCName
#
# Nazwy type NCName
#
#     NCName ::=  Name - (Char* ':' Char*)
#
#     Name ::= NameStartChar (NameChar)*
#
#     NameChar ::= NameStartChar | "-" | "." | [0-9] |
#     #xB7 | [#x0300-#x036F] | [#x203F-#x2040]
#
#     NameStartChar   ::= [A-Z] | "_" | [a-z] | [#xC0-#xD6] |
#     [#xD8-#xF6] | [#xF8-#x2FF] | [#x370-#x37D] |
#     [#x37F-#x1FFF] | [#x200C-#x200D] | [#x2070-#x218F] |
#     #x2C00-#x2FEF] | [#x3001-#xD7FF] | [#xF900-#xFDCF] |
#     [#xFDF0-#xFFFD] | [#x10000-#xEFFFF]
#
# Literały
#
# -   *Literał* jest wartością (która nie jest zasobem): tekstem
#     (*string*), liczbą lub datą.
#
# -   Każdy literał należy do dokładnie jednego typu danych (*datatype*),
#     np.:
#
#     -   liczba całkowita
#         (<https://www.w3.org/TR/xmlschema11-2/#integer>)
#
#     -   wartość boole’owska
#         (<https://www.w3.org/TR/xmlschema11-2/#boolean>)
#
#     -   tekst (<https://www.w3.org/TR/xmlschema11-2/#string>)
#
#     -   …
#
# -   Literał składa się z 2 (lub 3) części:
#
#     1.  formy leksykalnej
#
#     2.  (IRI dla) typu danych
#
#     3.  jeżeli typ danych jest równy
#         <http://www.w3.org/1999/02/22-rdf-syntax-ns#langString>,
#         znacznika języka.
#
# Serializacje grafów RDF – XML
#
# ![image](img/rdftripleex.jpg)
#
# $<$rdf:Description rdf:about="http://dbpedia.org/resource/Garbacz"$>$
# $<$dbo:isPartOf
# rdf:resource="http://dbpedia.org/resource/Ostrowiec_County" /$>$
# $<$/rdf:Description$>$
#
# Serializacje grafów RDF – JSON
#
# ![image](img/rdftripleex.jpg)
#
# $\{$
# "http://en.wikipedia.org/wiki/Garbacz" :
# "http://dbpedia.org/ontology/isPartOf" :
# $[$ $\{$ "type" : "uri", "value" :
# "http://dbpedia.org/resource/Ostrowiec_County" $\}$ $]$
# $\}$
#
# Serializacje grafów RDF – N-Triples
#
# ![image](img/rdftripleex.jpg)
#
# $<$http://dbpedia.org/resource/Garbacz$>$
# $<$http://dbpedia.org/ontology/isPartOf$>$
# $<$http://dbpedia.org/resource/Ostrowiec_County$>$ .
#
# Serializacje grafów RDF – Turtle
#
# ![image](img/rdftripleex.jpg)
#
# @ prefix dbr: $<$http://dbpedia.org/resource/$>$ .
# @ prefix dbo: $<$http://dbpedia.org/ontology/$>$ .
# dbr:Garbacz dbo:isPartOf dbr:Ostrowiec_County .
#
# Seralizacja literałów – Turtle
#
# ![image](img/rdftripleex3.jpg)
#
# @prefix dbr: $<$http://dbpedia.org/resource/$>$ .
# @prefix dbp: $<$http://dbpedia.org/property/$>$ .
# dbr:Garbacz dbp:name "Garbacz"@en .
#
# Seralizacja literałów – Turtle (2)
#
# ![image](img/rdftripleex2.jpg)
#
# @prefix dbr: $<$http://dbpedia.org/resource/$>$ .
# @prefix dbo: $<$http://dbpedia.org/ontology/$>$ .
# @prefix geo: $<$http://www.w3.org/2003/01/geo/wgs84_pos#$>$ .
# @prefix virtrdf: $<$http://www.openlinksw.com/schemas/virtrdf#$>$ .
# dbr:Garbacz geo:geometry "POINT(21.228332519531
# 50.874443054199)"^^virtrdf:Geometry .

# %% [markdown]
# ## RDFS
#
# RDFS jako słownik RDF
#
# RDFS jako słownik RDF – przestrzenie nazw
#
# 1.  rdf – <http://www.w3.org/1999/02/22-rdf-syntax-ns>
#
# 2.  rdfs – <https://www.w3.org/2000/01/rdf-schema>
#
# Podstawowe pojęcia RDFS
#
# 1.  klasy i pojęcia pokrewne
#
# 2.  własności i pojęcia pokrewne
#
# Klasy w RDFS
#
# 1.  rdfs:Class
#
# 2.  rdf:type
#
# 3.  IRI rdf:type rdfs:Class
#
# 4.  IRI#1 rdf:type IRI#2
#
# 5.  przykłady:
#
#     -   dbo:Place rdf:type rdfs: Class
#
#     -   dbr:Garbacz rdf:type dbo:Place
#
# Relacje pomiędzy klasami w RDFS
#
# 1.  rdfs:subClassOf
#
# 2.  IRI#1 rdfs:subClassOf IRI#2
#
# 3.  przykłady:
#
#     -   dbo:Place rdf:subClassOf rdfs:Location
#
#     -   dbo:Park rdf:subClassOf rdfs:Place
#
# Relacje pomiędzy klasami w RDFS – funkcje semantyczne
#
# 1.  przechodność rdfs:subClassOf
#
# 2.  związek z rdf:type
#
# Przechodność rdfs:subClassOf
#
# 1.  IRI#1 rdfs:subClassOf IRI#2
#
# 2.  IRI#2 rdfs:subClassOf IRI#3
#
# 3.  IRI#1 rdfs:subClassOf IRI#3
#
#     -   dbo:Place rdf:subClassOf rdfs:Location
#
#     -   dbo:Park rdf:subClassOf rdfs:Place
#
#     -   dbo:Park rdfs:subClassOf rdfs:Location
#
# Rdf:type w kontekście rdfs:subClassOf
#
# 1.  IRI#1 rdf:type IRI#2
#
# 2.  IRI#2 rdfs:subClassOf IRI#3
#
# 3.  IRI#1 rdf:type IRI#3
#
#     -   dbr:Garbacz rdf:type dbo:Place
#
#     -   dbo:Place rdf:subClassOf rdfs:Location
#
#     -   dbr:Garbacz rdf:type dbo:Location
#
# Własności/relacje w RDFS
#
# 1.  rdf:Property
#
# 2.  IRI rdf:type rdf:Property
#
# 3.  przykłady:
#
#     -   dbo:isPartOf rdf:type rdf:Property
#
# Relacje pomiędzy własnościami w RDFS
#
# 1.  rdfs:subPropertyOf
#
# 2.  IRI#1 rdfs:subPropertyOf IRI#2
#
# 3.  przykłady:
#
#     -   dbo:isPartOfWineRegion rdf:subPropertyOf rdfs:isPartOf
#
# Dziedzina i przeciwdziedzina własności/relacji w RDFS
#
# 1.  rdfs:domain
#
# 2.  rdfs:range
#
# 3.  IRI#1 rdfs:domain IRI#2
#
# 4.  IRI#1 rdfs:range IRI#2
#
# 5.  przykłady:
#
#     -   dbo:isPartOfWineRegion rdf:domain dbo:WineRegion
#
#     -   dbo:isPartOfWineRegion rdf:range dbo:WineRegion
#
# Dziedzina i przeciwdziedzina własności/relacji w RDFS – funkcje
# semantyczne
#
# 1.  IRI#1 rdfs:domain IRI#2
#
# 2.  IRI#3 IRI#1 IRI#4
#
# 3.  IRI#3 rdf:type IRI#2
#
# 4.  przykłady:
#
#     -   dbo:hubAirport rdf:domain dbo:Airline
#
#     -   dbr: LOT$\_$Polish$\_$Airlines dbo:hubAirport dbr:Garbacz
#
#     -   dbr: LOT$\_$Polish$\_$Airlines rdf:type dbo:airline
#
# Przeciwdziedzina własności/relacji w RDFS – funkcje semantyczne
#
# 1.  IRI#1 rdfs:range IRI#2
#
# 2.  IRI#3 IRI#1 IRI#4
#
# 3.  IRI#4 rdf:type IRI#2
#
# 4.  przykłady:
#
#     -   dbo:hubAirport rdf:range dbo:Airport
#
#     -   dbr: LOT$\_$Polish$\_$Airlines dbo:hubAirport dbr:Garbacz
#
#     -   dbr:Garbacz rdf:type dbo:Airport
#
# Użyteczne relacje RDFS
#
# 1.  rdfs:label
#
# 2.  rdfs:comment
#
# 3.  rdfs:seeAlso
#
# 4.  rdfs:isDefinedBy
#
# 5.  rdfs:value
#
# Pominięte elementy RDFS
#
# 1.  zasobniki RDFS
#
# 2.  kolekcje RDFS
#
# 3.  (pod-)słownik reifikacyjny
