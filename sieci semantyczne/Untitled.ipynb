# %% [markdown]
# Uniwersytecki sawuar wiwr
# =========================
#
# -   punktualność uczestników -- zasada kwadransa
#
# -   kultura słuchaczy -- milcz i pozwól milczeć innym
#
# -   spryt studentów a rzeczywistość skrzeczy
#
# O wykładzie
# ===========
#
# -   wykład: 30 godzin tj. 15 $\times$ (2 $\times$ 45 minut + sik-pausa)
#
# -   obecność
#
# -   materiały pomocnicze
#
#     -   Google is your friend: 'knowledge representation'
#
# -   egzamin ustny
#
# -   uczelniane *Wunderwaffe* : konsultacje\
#
#     czwartek\
#     $10^{20}-11^{40}$
#
# -   [garbacz\@kul.pl](garbacz@kul.pl)
#
# O wykładzie (2)
# ===============
#
# -   hasła - mniej ważne informacje
#
# -   Ważne definicje są zapisane pełnymi zdaniami, a terminy definiowane
#     są w *kursywie*.
#
# Długie i *bardzo* ważne definicje są podawane w ramkach.
#
# Menu
# ====
#
# Reprezentacja wiedzy
# ====================
#
# Reprezentacja wiedzy
# ====================
#
# > Reprezentacja wiedzy jest multidyscyplinarną dziedziną, która stosuje
# > teorie i metody z trzech obszarów:
# >
# > 1.  *logiki* \[która\] określa formalną strukturę \[reprezentacji
# >     wiedzy\] i reguły wnioskowania
# >
# > 2.  *ontologii* \[która\] definiuje rodzaje rzeczy, które istnieją w
# >     dziedzinie zastosowania \[reprezentacji wiedzy\]
# >
# > 3.  *informatyki* (*computation*) \[która\] wspiera aplikacje
# >     odróżniające reprezentację wiedzy od czystej filozofii
# >
# > [@Sowa-Knowledge-2000 s. XI-XII]
#
# Reprezentacja wiedzy (trochę prościej)
# ======================================
#
# -   Jak zapisać wiedzę w komputerze, aby
#
#     -   komputer umiał:
#
#         -   generować nową wiedzę z wiedzy powierzonej, gdy potrzebna
#             jest ona do rozwiązania jakiegoś problemu
#
#         -   umiał dzielić się wiedzą z innymi komputerami
#
#     -   ludzie
#
# Reprezentacja wiedzy a sztuczna inteligencja
# ============================================
#
# Dłuższa historia SI
# ===================
#
# -   pierwsza wiosna SI (1950 -- 1960)
#
#     -   *Look, Ma, no hands!*
#
#     -   test Turinga (1950)
#
#     -   konferencja w Dartmouth (1956): J. McCarthy, R. Solomonoff, C.
#         Shannon, A. Newell, H. Simon, M. Minsky
#
#     -   Logic Theorist, General Problem Solver, Shakey, ELIZA
#
# -   pierwsza zima SI (1960 -- 1970)
#
#     -   czysta syntaksa: 'the spirit is willing but the flesh is weak'
#         $>$ ...$>$ 'the vodka is good but the meat is rotten'
#
#     -   złożoność obliczeniowa: *Boy, this is a lot of possibilities!*
#
#     -   raport Lighthilla (1973)
#
# -   drugia wiosna SI (1970 -- 1980)
#
#     -   systemy eksperckie i bazy wiedzy
#
#     -   DENDRAL, MYCIN, CYC
#
# -   druga zima SI --
#
#     -   *That costs a lot ...*
#
# -   trzecia wiosna SI (1990 -- )
#
#     -   konekcjonizm vs logicyzm
#
#     -   sieci neuronowe i algorytmy genetyczne
#
#     -   komercjalizacja
#
# Jak myśli komputer?
# ===================
#
# Maszyna Turinga
# ===============
#
# ![image](TuringMachine.eps)
#
# *Maszyna Turinga* jest siódemką
# $<S, s_{0}, Q, L, \emptyset, I, \delta>$:
#
# 1.  skończony zbiór $S$ możliwych stanów maszyny z wyróżnionym stanem
#     początkowym $s_{0}$ i stanami końcowymi (akceptującymi)
#     $Q \subseteq S$;
#
# 2.  skończony zbiór symboli $L$ z symbolem pustym $\emptyset \in L$ oraz
#     podzbiorem symboli początkowych $I \subset L$;
#
# 3.  funkcja przejścia
#     $\delta: S \times L \to S \times L \times \{\text{w lewo}, \text{stój}, \text{w prawo}\}$.
#
# <https://turingmachinesimulator.com/>
# =====================================
#
# Jak komputer rozumie język polski?
# ==================================
#
# 0.5 Warszawa jest stolicą Polski.
#
# 0.5 01010111 01100001 01110010 01110011 01111010 01100001 01110111
# 01100001 00100000 01101010 01100101 01110011 01110100 00100000 01110011
# 01110100 01101111 01101100 01101001 01100011 11000100 10000101 00100000
# 01010000 01101111 01101100 01110011 01101011 01101001 00101110
#
# Jak komputer rozumie język polski?
# ==================================
#
# 0.5 Warszawa jest stolicą Polski.
#
# 0.5 01010111 01100001 01110010 01110011 01111010 01100001 01110111
# 01100001 00100000 01101010 01100101 01110011 01110100 00100000 00100000
# 01110011 01110100 01101111 01101100 01101001 01100011 11000100 10000101
# 00100000 01010000 01101111 01101100 01110011 01101011 01101001 00101110
#
# Jak komputer rozumie język polski?
# ==================================
#
# 0.5 Stolicą Polski jest Warszawa.
#
# 0.5 01010011 01110100 01101111 01101100 01101001 01100011 11000100
# 10000101 00100000 01010000 01101111 01101100 01110011 01101011 01101001
# 00100000 01101010 01100101 01110011 01110100 00100000 01010111 01100001
# 01110010 01110011 01111010 01100001 01110111 01100001 00101110
#
# Jak komputer rozumie język polski?
# ==================================
#
# 0.5 Warszawa jest siedzibą rządu Polski.
#
# 0.5 01010111 01100001 01110010 01110011 01111010 01100001 01110111
# 01100001 00100000 01101010 01100101 01110011 01110100 00100000 01110011
# 01101001 01100101 01100100 01111010 01101001 01100010 11000100 10000101
# 00100000 01110010 01111010 11000100 10000101 01100100 01110101 00100000
# 01010000 01101111 01101100 01110011 01101011 01101001 00101110
#
# Jak komputer rozumie język polski?
# ==================================
#
# 0.5 ?\*\*\*\*\*\*\*\*\*\*\*\*\*\*\*\*\*\*\*?
#
# 0.5 00111111 00101010 00101010 00101010 00101010 00101010 00101010
# 00101010 00101010 00101010 00101010 00101010 00101010 00101010 00101010
# 00101010 00101010 00101010 00101010 00101010 00111111
#
# Metody reprezentacji wiedzy
# ===========================
#
# 1.  wersja mini - semantyka w metadanych
#
# 2.  ...
#
# 3.  wersja maxi - semantyka w logice
#
# Wiedza odziana w metadane
# =========================
#
# -   dane o danych
#
# -   metadane dla reprezentacji wiedzy (nie-potocznej):
#
#     1.  MARC standard
#
# -   XML jako alfabet metadanych=znaczników
#
#     -   *e**x**tensible **m**arkup **l**anguage*
#
#     -   język znaczników (*tags*) = metajęzyk
#
#     -   schemat XML definiuje układ znaczników
#
# -   przykład\
#     $<$capital\_cities$\_$data$>$\
#     $<$item$>$\
#     $<$city$>$**Warszawa**$<$/city$>$\
#     $<$country$>$**Polska**$<$/country$>$\
#     $<$/item$>$\
#     $<$/geographic$\_$data$>$\
#
# Wiedza w metadanych - [schema.org](schema.org)
# ==============================================
#
# -   drzewo znaczników HTML (*HTML tags*), które są/będą wykorzystywane
#     przez Google, Yahoo! oraz Bing do wyszukiwania informacji
#
# -   część standardu HTML5
#
# -   typ mikrodanych
#
# [schema.org](schema.org) (2)
# ============================
#
# Restauracja "MAGIA"\
# 20-114 Lublin\
# ul. Rybna 1 / Grodzka 2\
# **RESTAURACJA: kontakt, rezerwacje:** tel. +48 (81) 5323041
#
# $<$p align=\"center\"$>$ Restauracja $\&$quot;MAGIA$\&$quot; $<$/p$>$\
# $<$br$>$\
# 20-114 Lublin$<$br$>$\
# ul. Rybna 1 / Grodzka 2 $<$br$>$\
# $<$p align=\"center\"$>$ $<$br$>$\
# $<$b$>$ $\&$nbsp;$\&$nbsp;$\&$nbsp;RESTAURACJA: kontakt, rezerwacje\
# $<$/b$>$ $<$br$>$\
# tel. +48 (81) 532304 $<$/p$>$\
# $<$p align=\"center\"$>$\
# $<$div [itemscope itemtype=\"http://schema.org/Restaurant\"]{.alert}$>$\
#  $<$span [itemprop=\"name\"$>$]{.alert}Restauracja
# $\&$quot;MAGIA$\&$quot; $<$/span$>$\
# $<$/p$>$ $<$br$>$\
#  $<$div [itemprop=\"address\" itemscope
# itemtype=\"http://schema.org/PostalAddress\"]{.alert}$>$ $<$br$>$\
#    $<$span [itemprop=\"postalCode\"]{.alert}$>$ 20-114 Lublin$<$/span$>$
# $<$br$>$\
#    $<$span [itemprop=\"streetAddress\"]{.alert}$>$ul. Rybna 1 / Grodzka
# 2$<$/span$>$\
#  $<$/div$>$\
# $<$p align=\"center\"$>$ $<$br$>$\
#  $<$b$>$ $\&$nbsp;$\&$nbsp;$\&$nbsp;RESTAURACJA: kontakt, rezerwacje\
#  $<$/b$>$ $<$br$>$\
#  $<$span [itemprop=\"telephone\"]{.alert}$>$+48 (81) 532304$<$/span$>$\
# $<$/p$>$ $<$/div$>$

# %% [markdown]
# b

# %% [markdown]
# c

# %% [markdown]
# Tablice analityczne -- skąd je brać? (3)
# ========================================
#
# -   [\[TA7\]]{#TA7 label="TA7"} $\mathbb{TOE}$: \] \[.$\neg \phi$
#     \[.$\neg \psi$ \] \] \]
#
# -   [\[TA8\]]{#TA8 label="TA8"} $\mathbb{TONK}$:
#
# -   [\[TA9\]]{#TA9 label="TA9"} $\mathbb{TONA}$: \] \]
#
# Tablice analityczne -- skąd je brać? (4)
# ========================================
#
# -   [\[TA10\]]{#TA10 label="TA10"} $\mathbb{TONC}$: \] \]
#
# -   [\[TA11\]]{#TA11 label="TA11"} $\mathbb{TONE}$: \] \[.$\neg \phi$
#     \[.$\psi$ \] \] \]
